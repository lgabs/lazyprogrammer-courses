# %%
from typing import Union, List
import numpy as np
import matplotlib.pyplot as plt
import string
import random
import re
import requests
import os
import textwrap
import nltk
from nltk.stem import WordNetLemmatizer
from bs4 import BeautifulSoup

# %% [markdown]
# ## Building Trigram Model
#
# output should be like:
#
# {
#     ("I", "eggs"): {
#         "like": 0.67,
#         "love": 0.21,
#         ...
#     }
# }

# %%
# basic corpus to test
basic_corpus = """
    I like cats
    I like pizzas
    I want water
    He wants water
"""

# %%
# !ls ../sentiment-analysis/electronics/
# Out:
# negative.review  positive.review  unlabeled.review

# %%
positive_reviews = BeautifulSoup(open("../sentiment-analysis/electronics/positive.review").read(), features="html5lib").findAll("review_text")

# %%
positive_reviews[0]
# Out:
# <review_text>
# I purchased this unit due to frequent blackouts in my area and 2 power supplies going bad.  It will run my cable modem, router, PC, and LCD monitor for 5 minutes.  This is more than enough time to save work and shut down.   Equally important, I know that my electronics are receiving clean power.
#
# I feel that this investment is minor compared to the loss of valuable data or the failure of equipment due to a power spike or an irregular power supply.
#
# As always, Amazon had it to me in &lt;2 business days
# </review_text>

# %% [markdown]
# ## Language Model

# %%
# leveraging ord function to get integers from a character to use as index
ord("a"), ord("b"), ord("c")
# Out:
# (97, 98, 99)

# %% [markdown]
# markov matrix to store trigram probabilities
#
# we initialize with ones to consider "add-one smoothing"
#
# On the cipher exercise, we were using unigram and bigram calculations. For unigrams, it is easy: we just count words. For bigrams, we needed the unigram prob, so for $n-gram$ models we need all previous probabilities.
#
# In general, a trigram and $n-gram$ model have the following probabilities:
#
# $$p(w_t| w_{t-1}, w_{t-2}) = \frac{p(w_{t-2}\rightarrow w_{t-1} \rightarrow w_{t})}{p(w_{t-2}\rightarrow w_{t-1})} $$
#
# $$p(w_t| w_{t-1}, w_{t-2}, ...,w_{t-N+1}) = \frac{p(w_{t-N+1}\rightarrow ... \rightarrow w_{t-1} \rightarrow w_{t})}{p(w_{t-N+1}\rightarrow ... \rightarrow w_{t-1} )} $$
#
# Hence, the general formula is recursive.

# %%
# define which n-gram we want
ngram = 3 #trigram

M_2 = np.ones((26,26))

# initial state distribution (unigrams probabilities)
pi = np.zeros(26)

def update_trigrams(w1, w2, w3):
    pass

def update_bigrams(w1, w2):
    i = ord(w1) - 97
    j = ord(w2) - 97
    M[i,j] += 1
    
def update_unigrams(w):
    i = ord(w) - 97
    pi[i] += 1
    
# get log-probability of a word/token
def get_word_prob(word):
    
    probs = []
    # first word index
    i = ord(word[0]) - 97
    probs.append(np.log(pi[i]))
    
    # rest of sentence
    for w_previous, w in zip(word, word[1:]):
        i = ord(w_previous) - 97
        j = ord(w) - 97
        probs.append(np.log(M[i,j]))
        
    # find log-probability
    return sum(probs)

# get log-probability of a document, which is a sequence of words
def get_sequence_prob(doc:Union[str, List]):
    
    if type(doc) == str:
        doc = doc.split()
        
    prob = 0
    for word in doc:
        prob += get_word_prob(word)
        
    return prob

# %%
l = [1,2,4,5]
l[:-2]
# Out:
# [1, 2]

# %%
regex = re.compile('[^a-zA-Z]')

trigrams = {}
lemmatizer = WordNetLemmatizer()

with open("../sentiment-analysis/stopwords.txt") as f:
    stopwords = set(w.rstrip for w in f)

def my_tokenizer(sentence:str):
    s = sentence.lower()
    s = regex.sub(' ', s) 
    tokens = nltk.tokenize.word_tokenize(s)
    tokens = [t for t in tokens if len(t) > 2]
    tokens = [lemmatizer.lemmatize(t) for t in tokens]
    tokens = [t for t in tokens if t not in stopwords]

    return tokens

for review in positive_reviews:
    tokens = my_tokenizer(review.text)
    if tokens:
        # update our language model 
        for i, token in enumerate(tokens[:-2]):
            # update first unigram probs
            k = (tokens[i], tokens[i+2])
            if k not in trigrams:
                trigrams[k] = []
            # update the middle words seen on the example
            trigrams[k].append(tokens[i+1])
            
            
#             update_unigrams(ch0)
            
#             # update bigrams for the other letters
#             for ch1 in token[1:]:
#                 update_bigrams(ch0, ch1)
#                 ch0 = ch1
                
            # update trigram probs
            

trigrams_probabilities = {}
for k, words in positive_reviews.items():
    if len(set(words)) > 1:
        d = {}
        n = 0
        for word in words:
            if word not in d:
                d[word] = 0
            d[word] += 1
            n += 1
        for w, c in d.items():
            d[w] = float(c) / n
            
        trigrams_probabilities[k] = d
            
# normalize probabilities
# pi /= pi.sum()
# M /= M.sum(axis=1, keepdims=True)

# %%
trigrams
# Out:
# {('purchased', 'unit'): ['this', 'the'],
#  ('this', 'due'): ['unit'],
#  ('unit', 'frequent'): ['due'],
#  ('due', 'blackout'): ['frequent'],
#  ('frequent', 'area'): ['blackout'],
#  ('blackout', 'and'): ['area'],
#  ('area', 'power'): ['and'],
#  ('and', 'supply'): ['power'],
#  ('power', 'going'): ['supply'],
#  ('supply', 'bad'): ['going'],
#  ('going', 'will'): ['bad'],
#  ('bad', 'run'): ['will'],
#  ('will', 'cable'): ['run'],
#  ('run', 'modem'): ['cable'],
#  ('cable', 'router'): ['modem', 'modem'],
#  ('modem', 'and'): ['router', 'phone', 'router'],
#  ('router', 'lcd'): ['and'],
#  ('and', 'monitor'): ['lcd', 'the'],
#  ('lcd', 'for'): ['monitor'],
#  ('monitor', 'minute'): ['for'],
#  ('for', 'this'): ['minute',
#   'le',
#   'hour',
#   'feedback',
#   'compatibility',
#   'security',
#   'sure',
#   'sure',
#   'spec',
#   'organization',
#   'more',
#   'the',
#   'traveling',
#   'use',
#   'amazon',
#   'vonage'],
#  ('minute', 'more'): ['this'],
#  ('this', 'than'): ['more', 'device', 'more'],
#  ('more', 'enough'): ['than', 'than', 'than', 'than', 'than'],
#  ('than', 'time'): ['enough', 'four', 'expected'],
#  ('enough', 'save'): ['time', 'space'],
#  ('time', 'work'): ['save', 'for'],
#  ('save', 'and'): ['work', 'some'],
#  ('work', 'shut'): ['and'],
#  ('and', 'down'): ['shut', 'transient', 'cool'],
#  ('shut', 'equally'): ['down'],
#  ('down', 'important'): ['equally'],
#  ('equally', 'know'): ['important'],
#  ('important', 'that'): ['know', 'remember'],
#  ('know', 'electronics'): ['that'],
#  ('that', 'are'): ['electronics',
#   'scratch',
#   'they',
#   'there',
#   'statement',
#   'there',
#   'you',
#   'you',
#   'they',
#   'battery',
#   'these',
#   'you',
#   'they',
#   'there'],
#  ('electronics', 'receiving'): ['are'],
#  ('are', 'clean'): ['receiving'],
#  ('receiving', 'power'): ['clean'],
#  ('clean', 'feel'): ['power'],
#  ('power', 'that'): ['feel', 'supply'],
#  ('feel', 'this'): ['that'],
#  ('that', 'investment'): ['this'],
#  ('this', 'minor'): ['investment'],
#  ('investment', 'compared'): ['minor'],
#  ('minor', 'the'): ['compared', 'excellent', 'note', 'criticism'],
#  ('compared', 'loss'): ['the'],
#  ('the', 'valuable'): ['loss'],
#  ('loss', 'data'): ['valuable'],
#  ('valuable', 'the'): ['data'],
#  ('data', 'failure'): ['the'],
#  ('the', 'equipment'): ['failure'],
#  ('failure', 'due'): ['equipment'],
#  ('equipment', 'power'): ['due'],
#  ('due', 'spike'): ['power'],
#  ('power', 'irregular'): ['spike'],
#  ('spike', 'power'): ['irregular'],
#  ('irregular', 'supply'): ['power'],
#  ('power', 'always'): ['supply'],
#  ('supply', 'amazon'): ['always'],
#  ('always', 'had'): ['amazon'],
#  ('amazon', 'business'): ['had'],
#  ('had', 'day'): ['business', 'few', 'within'],
#  ('ordered', 'back'): ['apc'],
#  ('apc', 'ups'): ['back'],
#  ('back', 'the'): ['ups',
#   'exactly',
#   'soon',
#   'the',
#   'with',
#   'co',
#   'center',
#   'door',
#   'home'],
#  ('ups', 'recommendation'): ['the'],
#  ('the', 'employee'): ['recommendation'],
#  ('recommendation', 'mine'): ['employee'],
#  ('employee', 'who'): ['mine'],
#  ('mine', 'used'): ['who'],
#  ('who', 'work'): ['used'],
#  ('used', 'apc'): ['work'],
#  ('work', 'had'): ['apc', 'have', 'perfect'],
#  ('apc', 'them'): ['had'],
#  ('had', 'for'): ['them',
#   'now',
#   'coverage',
#   'going',
#   'mine',
#   'axim',
#   'expected',
#   'pocket',
#   'mine',
#   'epson',
#   'vonage',
#   'them',
#   'the',
#   'charged',
#   'now',
#   'this',
#   'this'],
#  ('them', 'about'): ['for', 'and', 'for'],
#  ('for', 'month'): ['about',
#   'about',
#   'over',
#   'about',
#   'about',
#   'two',
#   'about',
#   'over',
#   'almost',
#   'about',
#   'last',
#   'almost',
#   'the',
#   'couple',
#   'about',
#   'two',
#   'about',
#   'few',
#   'about',
#   'least'],
#  ('about', 'now'): ['month',
#   'month',
#   'month',
#   'that',
#   'month',
#   'year',
#   'year',
#   'month',
#   'month',
#   'year',
#   'month',
#   'month'],
#  ('month', 'without'): ['now'],
#  ('now', 'any'): ['without'],
#  ('without', 'problem'): ['any', 'any', 'any'],
#  ('any', 'they'): ['problem', 'problem', 'help'],
#  ('problem', 'functioned'): ['they'],
#  ('they', 'properly'): ['functioned'],
#  ('functioned', 'through'): ['properly'],
#  ('properly', 'few'): ['through'],
#  ('through', 'unexpected'): ['few'],
#  ('few', 'power'): ['unexpected'],
#  ('unexpected', 'interruption'): ['power'],
#  ('power', 'gladly'): ['interruption'],
#  ('interruption', 'order'): ['gladly'],
#  ('gladly', 'more'): ['order'],
#  ('order', 'the'): ['more', 'from', 'belonging'],
#  ('more', 'need'): ['the'],
#  ('the', 'arises'): ['need'],
#  ('need', 'pro'): ['arises'],
#  ('arises', 'large'): ['pro'],
#  ('pro', 'plug'): ['large'],
#  ('large', 'spacing'): ['plug'],
#  ('plug', 'good'): ['spacing'],
#  ('spacing', 'for'): ['good'],
#  ('good', 'power'): ['for'],
#  ('for', 'adapter'): ['power'],
#  ('power', 'simple'): ['adapter'],
#  ('adapter', 'design'): ['simple'],
#  ('simple', 'long'): ['design'],
#  ('design', 'cord'): ['long'],
#  ('long', 'con'): ['cord'],
#  ('cord', 'line'): ['con'],
#  ('con', 'conditioning'): ['line'],
#  ('line', 'usually'): ['conditioning'],
#  ('conditioning', 'expensive'): ['usually'],
#  ('usually', 'option'): ['expensive'],
#  ('wish', 'unit'): ['the'],
#  ('the', 'had'): ['unit',
#   'time',
#   'ipod',
#   'way',
#   'moment',
#   'output',
#   'disc',
#   'name',
#   'which',
#   'product',
#   'belkin',
#   'boonies',
#   'nano',
#   'unit',
#   'screen',
#   'can',
#   'cable',
#   'market',
#   'output',
#   'headset',
#   'closest',
#   'sportapros',
#   'others',
#   'mdr',
#   'player',
#   'cord'],
#  ('unit', 'separate'): ['had'],
#  ('had', 'online'): ['separate'],
#  ('separate', 'offline'): ['online'],
#  ('online', 'light'): ['offline'],
#  ('offline', 'when'): ['light'],
#  ('light', 'power'): ['when', 'additional'],
#  ('when', 'the'): ['power',
#   'lanning',
#   'pulled',
#   'went',
#   'unplug',
#   'cranked',
#   'increased',
#   'facing',
#   'connect',
#   'compared',
#   'using',
#   'work',
#   'buy',
#   'come',
#   'clipped',
#   'bought',
#   'hearing',
#   'listening',
#   'attached',
#   'playing',
#   'putting',
#   'found',
#   'slung',
#   'switch',
#   'using',
#   'listen',
#   'turn',
#   'turned',
#   'wa',
#   'wanted',
#   'traveling',
#   'putting',
#   'looped',
#   'kept',
#   'using'],
#  ('power', 'unit'): ['the', 'the'],
#  ('the', 'missing'): ['unit', 'feature'],
#  ('unit', 'the'): ['missing',
#   'for',
#   'clean',
#   'also',
#   'off',
#   'tune',
#   'pick',
#   'pick',
#   'for',
#   'one',
#   'and',
#   'over',
#   'call',
#   'find',
#   'and',
#   'ha',
#   'one',
#   'locate'],
#  ('missing', 'single'): ['the'],
#  ('the', 'red'): ['single'],
#  ('single', 'light'): ['red'],
#  ('red', 'turn'): ['light'],
#  ('light', 'off'): ['turn'],
#  ('turn', 'only'): ['off'],
#  ('off', 'when'): ['only'],
#  ('only', 'the'): ['when',
#   'work',
#   'problem',
#   'get',
#   'adjusted',
#   'problem',
#   'wa',
#   'use',
#   'hesitation',
#   'drawback',
#   'think',
#   'drawback',
#   'grabbed',
#   'good',
#   'covered',
#   'label',
#   'used',
#   'complaint',
#   'about',
#   'need',
#   'hear',
#   'downside',
#   'used',
#   'fit',
#   'good',
#   'covered',
#   'problem',
#   'downside'],
#  ('when', 'warning'): ['the'],
#  ('the', 'sound'): ['warning',
#   'warning',
#   'digital',
#   'pico',
#   'clearly',
#   'quality',
#   'overall',
#   'difference',
#   'song',
#   'amazing',
#   'poor',
#   'full',
#   'best',
#   'quality',
#   'speaker',
#   'beep',
#   'subtle',
#   'excellent',
#   'glass',
#   'picture',
#   'conversion'],
#  ('warning', 'the'): ['sound'],
#  ('sound', 'warning'): ['the'],
#  ('warning', 'like'): ['sound'],
#  ('sound', 'lot'): ['like'],
#  ('like', 'sound'): ['lot', 'testing'],
#  ('lot', 'you'): ['sound', 'equipment'],
#  ('sound', 'hear'): ['you', 'when'],
#  ('you', 'the'): ['hear',
#   'created',
#   'through',
#   'have',
#   'watch',
#   'get',
#   'change',
#   'change',
#   'found',
#   'have',
#   'connect',
#   'uninstall',
#   'using',
#   'merge',
#   'want',
#   'turn',
#   'set',
#   'see',
#   'given',
#   'save',
#   'hit',
#   'use',
#   'ask',
#   'need',
#   'risk',
#   'change',
#   'have',
#   'have',
#   'drain',
#   'heard',
#   'use',
#   'download',
#   'want',
#   'sync',
#   'leave',
#   'stop',
#   'need',
#   'need',
#   'use',
#   'left',
#   'break',
#   'wonder',
#   'drink',
#   'get',
#   'have',
#   'bought',
#   'slide',
#   'can',
#   'are',
#   'read',
#   'have',
#   'need',
#   'are',
#   'see',
#   'have',
#   'connect',
#   'thinking',
#   'press',
#   'take',
#   'use',
#   'use',
#   'using',
#   'can',
#   'change',
#   'want',
#   'for',
#   'increase',
#   'get',
#   'see',
#   'get',
#   'learned',
#   'turn',
#   'that',
#   'unlocked',
#   'list',
#   'editing'],
#  ('hear', 'house'): ['the'],
#  ('the', 'isn'): ['house',
#   'sound',
#   'computer',
#   'zip',
#   'urc',
#   'headset',
#   'interface',
#   'device'],
#  ('house', 'always'): ['isn'],
#  ('isn', 'easy'): ['always', 'that'],
#  ('always', 'tell'): ['easy'],
#  ('easy', 'what'): ['tell'],
#  ('tell', 'happening'): ['what'],
#  ('cheaper', 'thick'): ['than'],
#  ('than', 'case'): ['thick'],
#  ('thick', 'and'): ['case', 'line', 'larger'],
#  ('case', 'le'): ['and'],
#  ('and', 'prone'): ['le'],
#  ('le', 'breakage'): ['prone'],
#  ('prone', 'these'): ['breakage'],
#  ('breakage', 'slim'): ['these'],
#  ('these', 'case'): ['slim', 'jewel', 'slim'],
#  ('slim', 'memorex'): ['case'],
#  ('case', 'protect'): ['memorex'],
#  ('memorex', 'your'): ['protect'],
#  ('protect', 'cd'): ['your'],
#  ('your', 'most'): ['cd'],
#  ('cd', 'buyer'): ['most'],
#  ('most', 'will'): ['buyer', 'card', 'certainly'],
#  ('buyer', 'get'): ['will'],
#  ('will', 'them'): ['get',
#   'allow',
#   'satisfy',
#   'wear',
#   'love',
#   'order',
#   'cause'],
#  ('get', 'for'): ['them',
#   'case',
#   'one',
#   'them',
#   'ready',
#   'memory',
#   'lot',
#   'them',
#   'one'],
#  ('them', 'use'): ['for'],
#  ('for', 'dvd'): ['use', 'which', 'panasonic', 'your', 'pure'],
#  ('use', 'burning'): ['dvd'],
#  ('dvd', 'and'): ['burning',
#   'player',
#   'movie',
#   'wife',
#   'audio',
#   'newbie',
#   'player'],
#  ('burning', 'these'): ['and'],
#  ('and', 'are'): ['these',
#   'these',
#   'there',
#   'what',
#   'midranges',
#   'bicycle',
#   'they',
#   'series',
#   'they',
#   'there',
#   'memory',
#   'they',
#   'high',
#   'they',
#   'downloads',
#   'this',
#   'nanos',
#   'these',
#   'they',
#   'connector',
#   'you',
#   'instruction',
#   'thing',
#   'signal',
#   'they',
#   'they',
#   'they',
#   'these',
#   'height',
#   'remote',
#   'they',
#   'they',
#   'macro',
#   'they',
#   'color',
#   'nook'],
#  ('these', 'affordable'): ['are'],
#  ('are', 'choice'): ['affordable'],
#  ('affordable', 'from'): ['choice'],
#  ('choice', 'quality'): ['from'],
#  ('from', 'company'): ['quality', 'another'],
#  ('quality', 'for'): ['company', 'but', 'received', 'great', 'scanner'],
#  ('company', 'that'): ['for'],
#  ('for', 'purpose'): ['that', 'many', 'other', 'the', 'almost', 'archival'],
#  ('that', 'you'): ['purpose',
#   'let',
#   'way',
#   'matter',
#   'when',
#   'when',
#   'when',
#   'mean',
#   'what',
#   'when',
#   'let',
#   'when',
#   'when',
#   'give',
#   'what',
#   'routinely',
#   'let',
#   'mind',
#   'when',
#   'mean',
#   'and',
#   'let'],
#  ('purpose', 'may'): ['you'],
#  ('you', 'want'): ['may',
#   'don',
#   'might',
#   'you',
#   'may',
#   'may',
#   'need',
#   'just',
#   'will',
#   'might',
#   'not',
#   'might',
#   'may',
#   'just',
#   'don',
#   'don',
#   'just',
#   'need',
#   'might',
#   'may',
#   'don'],
#  ('may', 'consider'): ['want'],
#  ('want', 'larger'): ['consider'],
#  ('consider', 'case'): ['larger', 'having'],
#  ('larger', 'depending'): ['case'],
#  ('case', 'your'): ['depending'],
#  ('depending', 'taste'): ['your'],
#  ('your', 'but'): ['taste', 'body', 'eardrum', 'mind', 'ipod', 'hand'],
#  ('taste', 'otherwise'): ['but'],
#  ('but', 'these'): ['otherwise', 'find'],
#  ('otherwise', 'will'): ['these'],
#  ('these', 'probably'): ['will', 'are', 'will'],
#  ('will', 'satisfy'): ['probably', 'easily'],
#  ('probably', 'your'): ['satisfy'],
#  ('satisfy', 'need'): ['your'],
#  ('brought', 'card'): ['kingston'],
#  ('kingston', 'from'): ['card'],
#  ('card', 'amazon'): ['from'],
#  ('from', 'com'): ['amazon', 'amazon', 'amazon', 'amazon', 'amazon'],
#  ('amazon', 'recently'): ['com'],
#  ('com', 'according'): ['recently'],
#  ('recently', 'openion'): ['according'],
#  ('according', 'amazon'): ['openion'],
#  ('openion', 'one'): ['amazon'],
#  ('amazon', 'the'): ['one',
#   'had',
#   'during',
#   'had',
#   'win',
#   'page',
#   'had',
#   'having',
#   'for',
#   'almost'],
#  ('one', 'best'): ['the', 'the', 'the', 'the', 'the', 'the', 'the', 'the'],
#  ('the', 'online'): ['best'],
#  ('best', 'shopping'): ['online'],
#  ('online', 'market'): ['shopping'],
#  ('shopping', 'they'): ['market'],
#  ('market', 'deliver'): ['they'],
#  ('they', 'the'): ['deliver',
#   'hold',
#   'one',
#   'give',
#   'are',
#   'sound',
#   'are',
#   'amazed',
#   'serve',
#   'pain',
#   'get',
#   'are',
#   'reveal'],
#  ('deliver', 'product'): ['the'],
#  ('the', 'intime'): ['product'],
#  ('product', 'and'): ['intime', 'high', 'work', 'ad'],
#  ('intime', 'the'): ['and'],
#  ('and', 'item'): ['the', 'quality'],
#  ('the', 'brought'): ['item'],
#  ('item', 'far'): ['brought'],
#  ('brought', 'are'): ['far'],
#  ('far', 'working'): ['are'],
#  ('are', 'very'): ['working', 'not', 'few', 'also', 'both', 'few', 'then'],
#  ('working', 'well'): ['very'],
#  ('very', 'kingston'): ['well'],
#  ('well', 'card'): ['kingston'],
#  ('kingston', 'working'): ['card'],
#  ('card', 'very'): ['working', 'size', 'overall'],
#  ('working', 'good'): ['very'],
#  ('very', 'with'): ['good',
#   'happy',
#   'pleased',
#   'happy',
#   'pleased',
#   'low',
#   'satisfied',
#   'impressed',
#   'satisfied',
#   'happy',
#   'happy',
#   'impressed',
#   'pleased',
#   'happy',
#   'pleased',
#   'satisfied',
#   'happy',
#   'common',
#   'happy',
#   'happy',
#   'helpful',
#   'happy',
#   'happy',
#   'happy',
#   'satisfied',
#   'happy',
#   'pleased',
#   'pleased',
#   'pleased',
#   'pleased',
#   'happy',
#   'impressed',
#   'happy',
#   'sturdy',
#   'satisfied',
#   'pleased',
#   'happy',
#   'pleased',
#   'pleased',
#   'happy',
#   'confident',
#   'happy',
#   'satisfied',
#   'impressed',
#   'familiar',
#   'satisfied',
#   'happy',
#   'pleased',
#   'pleased',
#   'happy',
#   'impressed',
#   'pleased',
#   'happy',
#   'happy',
#   'happy',
#   'pleased',
#   'pleased',
#   'pleased'],
#  ('good', 'out'): ['with'],
#  ('with', 'giving'): ['out'],
#  ('out', 'any'): ['giving', 'nor'],
#  ('giving', 'problem'): ['any'],
#  ('any', 'one'): ['problem', 'bad'],
#  ('problem', 'can'): ['one', 'you', 'entirely'],
#  ('one', 'always'): ['can'],
#  ('can', 'amazon'): ['always'],
#  ('always', 'for'): ['amazon', 'that'],
#  ('amazon', 'online'): ['for'],
#  ('for', 'shopping'): ['online'],
#  ('online', 'bye'): ['shopping'],
#  ('shopping', 'kira'): ['bye'],
#  ('this', 'wa'): ['product',
#   'set',
#   'product',
#   'one',
#   'system',
#   'product',
#   'monitor',
#   'one',
#   'purchase',
#   'installation',
#   'case',
#   'review',
#   'product',
#   'device',
#   'splitter',
#   'purchase',
#   'unit',
#   'swivel',
#   'dock',
#   'modem',
#   'printer',
#   'one',
#   'phone',
#   'one',
#   'product',
#   'printer',
#   'phone',
#   'one',
#   'testing',
#   'product'],
#  ('product', 'perfect'): ['wa', 'wa'],
#  ('wa', 'sturdy'): ['perfect'],
#  ('perfect', 'case'): ['sturdy', 'ipod'],
#  ('sturdy', 'that'): ['case'],
#  ('case', 'hold'): ['that'],
#  ('that', 'large'): ['hold', 'ha'],
#  ('hold', 'collection'): ['large'],
#  ('large', 'and'): ['collection', 'enough', 'screen', 'screen', 'display'],
#  ('collection', 'dvd'): ['and'],
#  ('and', 'other'): ['dvd',
#   'some',
#   'the',
#   'many',
#   'the',
#   'the',
#   'far',
#   'the',
#   'compare',
#   'various',
#   'the',
#   'the',
#   'the'],
#  ('dvd', 'case'): ['other'],
#  ('other', 'were'): ['case'],
#  ('case', 'flimsy'): ['were'],
#  ('were', 'and'): ['flimsy',
#   'longer',
#   'recorded',
#   'brighter',
#   'dynamic',
#   'dropped',
#   'next'],
#  ('flimsy', 'wore'): ['and'],
#  ('and', 'out'): ['wore',
#   'found',
#   'come',
#   'figured',
#   'rock',
#   'sitting',
#   'tried',
#   'find',
#   'turned'],
#  ('wore', 'fast'): ['out'],
#  ('out', 'this'): ['fast', 'that', 'that', 'thumb', 'there'],
#  ('fast', 'one'): ['this', 'forward'],
#  ('this', 'ha'): ['one',
#   'recorder',
#   'phone',
#   'baby',
#   'would',
#   'model',
#   'keyboard',
#   'phone',
#   'monitor',
#   'sony',
#   'mount',
#   'card',
#   'one',
#   'card',
#   'unit',
#   'model',
#   'model',
#   'model',
#   'backpack',
#   'case',
#   'card',
#   'phone',
#   'monitor',
#   'samsung',
#   'system',
#   'player',
#   'gamepad',
#   'gamepad',
#   'unit',
#   'printer',
#   'product'],
#  ('one', 'hard'): ['ha'],
#  ('ha', 'outside'): ['hard'],
#  ('hard', 'shell'): ['outside'],
#  ('outside', 'and'): ['shell', 'window'],
#  ('shell', 'the'): ['and'],
#  ('and', 'inside'): ['the'],
#  ('the', 'hold'): ['inside', 'covered', 'case'],
#  ('inside', 'dvd'): ['hold'],
#  ('hold', 'nicely'): ['dvd'],
#  ('dvd', 'have'): ['nicely', 'ram', 'and', 'that'],
#  ('nicely', 'complaint'): ['have'],
#  ('have', 'and'): ['complaint',
#   'bought',
#   'mac',
#   'searched',
#   'searched',
#   'when',
#   'copy',
#   'freedom',
#   'something',
#   'directv',
#   'pick',
#   'gateway',
#   'engraved',
#   'had',
#   'tmj',
#   'laptop'],
#  ('complaint', 'the'): ['and',
#   'about',
#   'about',
#   'though',
#   'that',
#   'have',
#   'that',
#   'that',
#   'about'],
#  ('and', 'price'): ['the',
#   'good',
#   'fair',
#   'total',
#   'great',
#   'the',
#   'good',
#   'the',
#   'the',
#   'excellent',
#   'the',
#   'the',
#   'the',
#   'lower'],
#  ('the', 'paid'): ['price', 'wire', 'buck', 'price'],
#  ('price', 'say'): ['paid', 'for'],
#  ('paid', 'this'): ['say'],
#  ('say', 'wa'): ['this', 'this'],
#  ('this', 'great'): ['wa',
#   'product',
#   'one',
#   'radio',
#   'really',
#   'phone',
#   'product',
#   'make',
#   'radio',
#   'thing',
#   'transmitter',
#   'nano',
#   'thing',
#   'screen',
#   'card',
#   'device',
#   'keyboard',
#   'wa',
#   'wa',
#   'reciever'],
#  ('wa', 'deal'): ['great'],
#  ('great', 'for'): ['value',
#   'value',
#   'battery',
#   'product',
#   'back',
#   'value',
#   'way',
#   'cam',
#   'saving',
#   'price',
#   'value',
#   'quality',
#   'headset',
#   'feature',
#   'product',
#   'unit',
#   'phone',
#   'value',
#   'keyboard',
#   'value',
#   'buy',
#   'case',
#   'also',
#   'angle',
#   'gadget',
#   'value',
#   'buy'],
#  ('value', 'your'): ['for', 'for', 'then'],
#  ('for', 'money'): ['your',
#   'your',
#   'the',
#   'the',
#   'the',
#   'the',
#   'the',
#   'the',
#   'the',
#   'the',
#   'the',
#   'the',
#   'your',
#   'your',
#   'the',
#   'the',
#   'their',
#   'the',
#   'the',
#   'the',
#   'the',
#   'the'],
#  ('your', 'kingston'): ['money', 'money'],
#  ('money', 'ha'): ['kingston', 'kingston'],
#  ('kingston', 'always'): ['ha', 'ha'],
#  ('ha', 'been'): ['always', 'always', 'not', 'not'],
#  ('always', 'reliable'): ['been', 'been'],
#  ('been', 'memory'): ['reliable', 'reliable'],
#  ('reliable', 'chip'): ['memory', 'memory'],
#  ('memory', 'company'): ['chip', 'chip'],
#  ('chip', 'and'): ['company', 'company'],
#  ('company', 'the'): ['and', 'and', 'well'],
#  ('and', 'same'): ['the', 'the', 'the', 'the'],
#  ('the', 'go'): ['same', 'same', 'clip', 'saying', 'product'],
#  ('same', 'for'): ['go', 'go', 'go', 'go'],
#  ('go', 'this'): ['for', 'for'],
#  ('for', 'product'): ['this',
#   'the',
#   'this',
#   'this',
#   'great',
#   'this',
#   'the',
#   'this',
#   'the'],
#  ('like', 'much'): ['very', 'very'],
#  ('very', 'use'): ['much',
#   'much',
#   'easy',
#   'easy',
#   'clear',
#   'easy',
#   'easy',
#   'easy',
#   'easy',
#   'easy',
#   'easy',
#   'simple',
#   'easy'],
#  ('much', 'outdoor'): ['use', 'use'],
#  ('use', 'trail'): ['outdoor', 'outdoor'],
#  ('outdoor', 'camera'): ['trail', 'trail'],
#  ('trail', 'for'): ['camera', 'camera'],
#  ('camera', 'wild'): ['for', 'for'],
#  ('for', 'game'): ['wild', 'wild', 'the'],
#  ('wild', 'and'): ['game', 'game'],
#  ('game', 'hold'): ['and', 'and'],
#  ('and', 'several'): ['hold', 'hold'],
#  ('hold', 'picture'): ['several', 'several', 'about'],
#  ('several', 'and'): ['picture', 'picture', 'time', 'month'],
#  ('picture', 'ha'): ['and', 'and'],
#  ('and', 'been'): ['ha',
#   'ha',
#   'ha',
#   'ha',
#   'ha',
#   'have',
#   'have',
#   'have',
#   'have',
#   'have',
#   'have',
#   'having',
#   'have',
#   'generally'],
#  ('ha', 'the'): ['been',
#   'been',
#   'limit',
#   'certified',
#   'all',
#   'twice',
#   'bothered',
#   'switch',
#   'all',
#   'that',
#   'cut',
#   'broken',
#   'dent',
#   'been',
#   'wire',
#   'all',
#   'all',
#   'one',
#   'provided',
#   'close'],
#  ('been', 'camera'): ['the', 'the'],
#  ('the', 'all'): ['camera',
#   'camera',
#   'installation',
#   'bass',
#   'viewer',
#   'brightness',
#   'router',
#   'charger',
#   'movie',
#   'longest',
#   'surpassed',
#   'menu',
#   'speaker',
#   'headband',
#   'headband',
#   'microsoft'],
#  ('camera', 'kind'): ['all', 'all'],
#  ('all', 'weather'): ['kind', 'kind'],
#  ('kind', 'would'): ['weather', 'weather', 'mouse'],
#  ('weather', 'buy'): ['would', 'would'],
#  ('would', 'kingston'): ['buy', 'buy'],
#  ('buy', 'again'): ['kingston', 'them', 'kingston', 'one', 'one', 'these'],
#  ('had', 'with'): ['problem',
#   'success',
#   'problem',
#   'problem',
#   'problem',
#   'problem',
#   'problem',
#   'problem',
#   'problem',
#   'problem',
#   'problem',
#   'issue',
#   'problem',
#   'more',
#   'problem',
#   'problem',
#   'problem',
#   'trouble',
#   'problem',
#   'phone'],
#  ('problem', 'this'): ['with', 'with', 'find', 'with', 'making', 'with'],
#  ('with', 'card'): ['this', 'netgear', 'this', 'credit', 'adapter'],
#  ('this', 'and'): ['card',
#   'item',
#   'short',
#   'item',
#   'notebook',
#   'deluxe',
#   'purchase',
#   'kodak',
#   'brand',
#   'one',
#   'drive',
#   'good',
#   'viewsonic',
#   'monitor',
#   'base',
#   'base',
#   'card',
#   'investment',
#   'drive',
#   'minimal',
#   'thing',
#   'page',
#   'fixed',
#   'mouse',
#   'printer',
#   'enough',
#   'expected',
#   'one',
#   'software',
#   'stand',
#   'first',
#   'model',
#   'headset',
#   'protector',
#   'configuration',
#   'headset',
#   'charger',
#   'product',
#   'phone',
#   'one',
#   'modem',
#   'problem',
#   'mouse',
#   'phone',
#   'capacity',
#   'phone',
#   'hardware',
#   'switch',
#   'printer'],
#  ('card', 'the'): ['and',
#   'handle',
#   'drain',
#   'onto',
#   'support',
#   'all',
#   'like',
#   'and',
#   'plug'],
#  ('and', 'delivery'): ['the', 'service'],
#  ('the', 'wa'): ['delivery',
#   'remote',
#   'than',
#   'way',
#   'subject',
#   'service',
#   'box',
#   'thing',
#   'quality',
#   'sound',
#   'sound',
#   'answer',
#   'purchased',
#   'unit',
#   'sharp',
#   'price',
#   'communication',
#   'le',
#   'price',
#   'picture',
#   'subwoofer',
#   'diamondback',
#   'sound',
#   'sound',
#   'price',
#   'gamepad',
#   'market',
#   'packaging',
#   'interface',
#   'idea',
#   'price',
#   'past',
#   'product',
#   'mix',
#   'shipping',
#   'intall',
#   'equipment',
#   'sub',
#   'headset',
#   'device',
#   'destination',
#   'purchase',
#   'dock',
#   'that',
#   'software',
#   'software',
#   'machine',
#   'price',
#   'game',
#   'product',
#   'quality',
#   'pad',
#   'remote',
#   'headset',
#   'volume',
#   'srf',
#   'cable',
#   'house',
#   'ique',
#   'strap',
#   'price',
#   'mount',
#   'price',
#   'price',
#   'product',
#   'service',
#   'price',
#   'phone',
#   'wall',
#   'theater',
#   'antenna',
#   'problem',
#   'ring'],
#  ('delivery', 'prompt'): ['wa'],
#  ('wa', 'thank'): ['prompt'],
#  ('prompt', 'you'): ['thank', 'give'],
#  ('thank', 'muc'): ['you'],
#  ('after', 'through'): ['going', 'searching', 'going'],
#  ('going', 'the'): ['through',
#   'use',
#   'use',
#   'back',
#   'into',
#   'with',
#   'strong',
#   'through',
#   'buy',
#   'strong'],
#  ('through', 'review'): ['the', 'lot'],
#  ('the', 'bought'): ['review',
#   'review',
#   'reason',
#   'one',
#   'spec',
#   'quest',
#   'best',
#   'reason',
#   'package'],
#  ('review', 'this'): ['bought',
#   'for',
#   'here',
#   'because',
#   'bought',
#   'state',
#   'bash',
#   'about',
#   'found',
#   'recommending'],
#  ('bought', 'card'): ['this', 'two'],
#  ('this', 'for'): ['card',
#   'product',
#   'product',
#   'drive',
#   'monitor',
#   'question',
#   'wonderful',
#   'one',
#   'unit',
#   'iterm',
#   'router',
#   'product',
#   'item',
#   'out',
#   'regard',
#   'one',
#   'and',
#   'mouse',
#   'camera',
#   'online',
#   'phone',
#   'item',
#   'product',
#   'request',
#   'wa',
#   'unit',
#   'quality',
#   'card',
#   'perfect',
#   'perfect',
#   'card',
#   'printer',
#   'printer',
#   'backpack',
#   'cable',
#   'keyboard',
#   'card',
#   'receiver',
#   'headset',
#   'one',
#   'model',
#   'perfect',
#   'controller',
#   'headphone',
#   'perfect',
#   'one',
#   'cable',
#   'perfect',
#   'player',
#   'perfect',
#   'product',
#   'wonderful'],
#  ('card', 'canon'): ['for'],
#  ('for', 'digital'): ['canon', 'friend', 'every', 'your'],
#  ('canon', 'rebel'): ['digital'],
#  ('digital', 'far'): ['rebel'],
#  ('rebel', 'ha'): ['far'],
#  ('far', 'worked'): ['ha', 'ha'],
#  ('ha', 'fine'): ['worked', 'worked', 'worked', 'worked'],
#  ('worked', 'though'): ['fine'],
#  ('fine', 'don'): ['though'],
#  ('though', 'pretend'): ['don'],
#  ('don', 'expert'): ['pretend'],
#  ('pretend', 'digital'): ['expert'],
#  ('expert', 'photographer'): ['digital'],
#  ('digital', 'when'): ['photographer', 'receiver'],
#  ('photographer', 'the'): ['when'],
#  ('when', 'card'): ['the'],
#  ('the', 'empty'): ['card', 'medium'],
#  ('card', 'show'): ['empty'],
#  ('empty', 'shot'): ['show'],
#  ('show', 'available'): ['shot'],
#  ('shot', 'seems'): ['available'],
#  ('available', 'read'): ['seems'],
#  ('seems', 'reasonably'): ['read'],
#  ('read', 'fast'): ['reasonably'],
#  ('reasonably', 'though'): ['fast'],
#  ('fast', 'take'): ['though'],
#  ('though', 'bit'): ['take', 'may'],
#  ('take', 'longer'): ['bit'],
#  ('bit', 'than'): ['longer', 'wider', 'smaller', 'more', 'more', 'larger'],
#  ('longer', 'wa'): ['than'],
#  ('than', 'used'): ['wa'],
#  ('wa', 'with'): ['used',
#   'using',
#   'worse',
#   'solved',
#   'built',
#   'mislead',
#   'impressed',
#   'installed',
#   'pleased',
#   'pictured',
#   'familiar',
#   'but',
#   'pictured',
#   'plagued',
#   'happy',
#   'done'],
#  ('used', 'point'): ['with'],
#  ('with', 'and'): ['point',
#   'machine',
#   'this',
#   'iriver',
#   'window',
#   'mac',
#   'multiple',
#   'itunes',
#   'set',
#   'player',
#   'compact',
#   'case',
#   'keyboard',
#   'them',
#   'these',
#   'itrip',
#   'line',
#   'caller',
#   'netgear',
#   'laptop',
#   'laptop',
#   'motorola',
#   'type',
#   'printer',
#   'them',
#   'mouse',
#   'problem',
#   'laptop',
#   'the',
#   'dragon',
#   'mac',
#   'phone',
#   'already',
#   'player',
#   'install',
#   'starbucks',
#   'them',
#   'direction',
#   'purchase',
#   'friend',
#   'usb',
#   'friend',
#   'wireless',
#   'range',
#   'husband',
#   'mount',
#   'canon',
#   'street'],
#  ('point', 'shoot'): ['and'],
#  ('and', 'olympus'): ['shoot'],
#  ('shoot', 'and'): ['olympus'],
#  ('olympus', 'it'): ['and'],
#  ('and', 'smartmedia'): ['it'],
#  ('it', 'card'): ['smartmedia'],
#  ('happy', 'this'): ['with',
#   'purchased',
#   'with',
#   'with',
#   'with',
#   'with',
#   'made',
#   'with',
#   'with',
#   'with',
#   'with'],
#  ('with', 'product'): ['this',
#   'the',
#   'both',
#   'this',
#   'this',
#   'the',
#   'you',
#   'this',
#   'apple',
#   'this',
#   'this',
#   'the',
#   'the',
#   'the',
#   'sandisk',
#   'this',
#   'their',
#   'the',
#   'apc',
#   'their',
#   'this',
#   'wenger'],
#  ('this', 'fold'): ['product'],
#  ('product', 'super'): ['fold'],
#  ('fold', 'slim'): ['super'],
#  ('super', 'traveling'): ['slim'],
#  ('slim', 'with'): ['traveling'],
#  ('traveling', 'breeze'): ['with'],
#  ('with', 'pretty'): ['breeze'],
#  ('breeze', 'good'): ['pretty'],
#  ('pretty', 'sound'): ['good'],
#  ('good', 'not'): ['sound', 'disclaimer', 'but', 'stereo', 'you'],
#  ('sound', 'bose'): ['not'],
#  ('not', 'quality'): ['bose', 'the', 'great'],
#  ('bose', 'but'): ['quality'],
#  ('but', 'the'): ['for',
#   'then',
#   'sense',
#   'everything',
#   'enjoyable',
#   'for',
#   'with',
#   'not',
#   'only',
#   'wa',
#   'since',
#   'with',
#   'hoped',
#   'had',
#   'usually',
#   'soon',
#   'here',
#   'big',
#   'for',
#   'have',
#   'found',
#   'with',
#   'from',
#   'for',
#   'fact',
#   'get',
#   'for',
#   'like',
#   'due',
#   'then',
#   'out',
#   'with',
#   'doe',
#   'not',
#   'because',
#   'received'],
#  ('for', 'price'): ['the',
#   'the',
#   'the',
#   'good',
#   'the',
#   'the',
#   'the',
#   'this',
#   'full',
#   'the',
#   'the',
#   'the',
#   'that',
#   'decent',
#   'fantastic',
#   'the',
#   'the',
#   'the',
#   'it',
#   'the',
#   'the',
#   'the',
#   'the',
#   'the',
#   'the',
#   'the',
#   'the',
#   'the',
#   'the',
#   'the',
#   'the',
#   'the',
#   'the',
#   'the',
#   'the',
#   'the',
#   'the',
#   'the',
#   'the',
#   'the',
#   'the',
#   'it',
#   'the',
#   'excellent',
#   'the',
#   'everyday',
#   'the',
#   'the',
#   'the',
#   'the',
#   'low',
#   'the'],
#  ('the', 'very'): ['price',
#   'show',
#   'same',
#   'sound',
#   'bass',
#   'middle',
#   'response',
#   'result',
#   'mouse',
#   'labeling',
#   'design',
#   'radio',
#   'vol',
#   'bose',
#   'floor',
#   'player',
#   'sound',
#   'subwoofer',
#   'bottom',
#   'mouse',
#   'sound',
#   'range',
#   'usb',
#   'beginning',
#   'bass',
#   'picture',
#   'felt',
#   'design',
#   'difference',
#   'wire',
#   'hand'],
#  ('price', 'respectable'): ['very'],
#  ('very', 'had'): ['respectable', 'nice'],
#  ('respectable', 'almost'): ['had'],
#  ('had', 'year'): ['almost', 'improved', 'had'],
#  ('almost', 'and'): ['year', 'week', 'year', 'year', 'year'],
#  ('year', 'ha'): ['and', 'and'],
#  ('ha', 'along'): ['been'],
#  ('been', 'many'): ['along'],
#  ('along', 'weekend'): ['many'],
#  ('many', 'get'): ['weekend', 'hour'],
#  ('weekend', 'aways'): ['get'],
#  ('get', 'and'): ['aways', 'price', 'signal', 'lost'],
#  ('aways', 'work'): ['and'],
#  ('and', 'great'): ['work',
#   'ha',
#   'always',
#   'look',
#   'work',
#   'print',
#   'do',
#   'are',
#   'ha',
#   'audio',
#   'worked',
#   'make',
#   'worked',
#   'work',
#   'have',
#   'worked',
#   'work',
#   'sound',
#   'look',
#   'wa'],
#  ('work', 'use'): ['great', 'great'],
#  ('great', 'alot'): ['use'],
#  ('use', 'wa'): ['alot', 'downloading', 'well'],
#  ('alot', 'good'): ['wa'],
#  ('wa', 'purchase'): ['good', 'good', 'silly', 'good', 'great'],
#  ('good', 'for'): ['purchase',
#   'idea',
#   'price',
#   'logitech',
#   'sound',
#   'enough',
#   'reason',
#   'news',
#   'choice',
#   'value',
#   'case',
#   'deal',
#   'cadadate',
#   'skin',
#   'balance',
#   'great',
#   'value',
#   'value',
#   'headset',
#   'time',
#   'sound',
#   'especially',
#   'enough',
#   'design',
#   'while'],
#  ('bought', 'reader'): ['this'],
#  ('this', 'because'): ['reader',
#   'format',
#   'unit',
#   'mouse',
#   'base',
#   'hotas',
#   'item',
#   'one',
#   'online',
#   'product',
#   'one',
#   'purchase',
#   'star',
#   'may'],
#  ('reader', 'wanted'): ['because'],
#  ('because', 'avoid'): ['wanted'],
#  ('wanted', 'having'): ['avoid'],
#  ('avoid', 'camera'): ['having'],
#  ('having', 'and'): ['camera'],
#  ('camera', 'all'): ['and', 'however'],
#  ('and', 'it'): ['all', 'did', 'learning'],
#  ('all', 'cable'): ['it', 'not', 'these'],
#  ('it', 'attached'): ['cable'],
#  ('cable', 'download'): ['attached'],
#  ('attached', 'the'): ['download', 'even'],
#  ('download', 'picture'): ['the', 'the'],
#  ('the', 'and'): ['picture',
#   'charger',
#   'host',
#   'time',
#   'camera',
#   'attachment',
#   'king',
#   'past',
#   'past',
#   'wap',
#   'box',
#   'box',
#   'ipod',
#   'screen',
#   'laptop',
#   'card',
#   'signal',
#   'built',
#   'car',
#   'transmitter',
#   'video',
#   'earphone',
#   'quality',
#   'monitor',
#   'dvd',
#   'disc',
#   'buffer',
#   'disc',
#   'drm',
#   'cost',
#   'problem',
#   'high',
#   'installation',
#   'phone',
#   'cable',
#   'volume',
#   'quality',
#   'price',
#   'room',
#   'menu',
#   'water',
#   'buy',
#   'video',
#   'image',
#   'sound',
#   'printer',
#   'screen',
#   'tivoli',
#   'quality',
#   'player',
#   'cpu',
#   'fang',
#   'epson',
#   'market',
#   'sound',
#   'line',
#   'thing',
#   'house',
#   'light',
#   'comfort',
#   'mouse',
#   'price',
#   'ink',
#   'remote',
#   'value',
#   'speaker',
#   'manufacturing',
#   'drive',
#   'unit',
#   'pair',
#   'yesterday',
#   'bass',
#   'bpo',
#   'time',
#   'picture',
#   'sound',
#   'dust',
#   'samsungs',
#   'clarity',
#   'problem',
#   'device',
#   'side',
#   'time',
#   'volume',
#   'driver',
#   'router',
#   'network',
#   'picture',
#   'newer',
#   'keyboard',
#   'mouse',
#   'price',
#   'battery',
#   'middle',
#   'mids',
#   'wire',
#   'clock',
#   'bell',
#   'email',
#   'sound',
#   'sleakest',
#   'sound',
#   'quality',
#   'closet',
#   'floorboard',
#   'tupperware',
#   'pot',
#   'mac',
#   'pc',
#   'action',
#   'sensetivity',
#   'ipod',
#   'device',
#   'element',
#   'aspiring',
#   'year',
#   'bell',
#   'price',
#   'camera',
#   'city',
#   'install',
#   'receiver',
#   'weight',
#   'bass',
#   'nano',
#   'wringer',
#   'bullet',
#   'run',
#   'prince',
#   'guitar',
#   'quality',
#   'red',
#   'house',
#   'travel',
#   'range',
#   'way',
#   'zune',
#   'player',
#   'rattle',
#   'sound',
#   'button',
#   'transfer',
#   'rain',
#   'room',
#   'purchase',
#   'sound',
#   'cam',
#   'mic',
#   'bose',
#   'dock',
#   'back',
#   'cartridge',
#   'post',
#   'geforce',
#   'accuracy',
#   'color',
#   'beach',
#   'box',
#   'hotel',
#   'newer',
#   'unit',
#   'problem',
#   'analog',
#   'windex',
#   'sound',
#   'chord',
#   'wall',
#   'sound',
#   'blockiness',
#   'monster',
#   'white',
#   'ingeniousness',
#   'dvr',
#   'backpack',
#   'holder',
#   'back',
#   'ipod',
#   'past',
#   'layout',
#   'machine',
#   'internet',
#   'signal',
#   'past',
#   'drive',
#   'passionate',
#   'keyboard',
#   'room',
#   'floor',
#   'way',
#   'ipod',
#   'screen',
#   'imperfection',
#   'cord',
#   'set',
#   'scalp',
#   'band',
#   'road',
#   'dark',
#   'warranty',
#   'color',
#   'ear',
#   'size',
#   'older',
#   'ipod',
#   'cap',
#   'version',
#   'dwl',
#   'money',
#   'hardware',
#   'windsheild',
#   'middle',
#   'power',
#   'end',
#   'box',
#   'best',
#   'bottom',
#   'model',
#   'wire',
#   'airplane',
#   'travel',
#   'market',
#   'internet',
#   'state',
#   'office',
#   'control',
#   'eye',
#   'kitchen',
#   'base',
#   'past',
#   'wall',
#   'power',
#   'color',
#   'price',
#   'power',
#   'mouse',
#   'web',
#   'generic',
#   'lowrance',
#   'window',
#   'market',
#   'air',
#   'screen',
#   'wash',
#   'car',
#   'mids',
#   'year',
#   'outlet',
#   'hardware',
#   'product',
#   'cost',
#   'country',
#   'contract',
#   'case',
#   'one',
#   'key',
#   'package',
#   'stand',
#   'video',
#   'price',
#   'lowrence',
#   'gps',
#   'satellite',
#   'resolution',
#   'yard',
#   'function',
#   'player',
#   'list',
#   'middle',
#   'player',
#   'in',
#   'gamepad',
#   'pad',
#   'reception',
#   'keyboard',
#   'display',
#   'street',
#   'picture',
#   'picture',
#   'adapter'],
#  ('picture', 'with'): ['and'],
#  ('and', 'this'): ['with',
#   'using',
#   'reliable',
#   'feel',
#   'feature',
#   'found',
#   'buy',
#   'whistle',
#   'mile',
#   'tracking',
#   'chose',
#   'mention',
#   'picked',
#   'elsewhere',
#   'stumbled',
#   'use',
#   'deemed',
#   'keeping',
#   'family',
#   'overall',
#   'superb',
#   'pop',
#   'recommend',
#   'preamp',
#   'surround',
#   'shoulder',
#   'use'],
#  ('with', 'reader'): ['this'],
#  ('this', 'could'): ['reader', 'because', 'you', 'but', 'dashmount'],
#  ('reader', 'leave'): ['could'],
#  ('could', 'camera'): ['leave'],
#  ('leave', 'and'): ['camera'],
#  ('camera', 'it'): ['and', 'with'],
#  ('and', 'cable'): ['it', 'for', 'speaker', 'regular', 'the'],
#  ('it', 'it'): ['cable'],
#  ('cable', 'case'): ['it'],
#  ('it', 'and'): ['case', 'rating', 'large', 'screen', 'cute', 'price', 'cute'],
#  ('case', 'just'): ['and', 'and'],
#  ('and', 'download'): ['just', 'transfering', 'almanac'],
#  ('just', 'the'): ['download',
#   'adjusting',
#   'added',
#   'simply',
#   'followed',
#   'put',
#   'fit',
#   'like',
#   'wish',
#   'focus',
#   'right',
#   'wanted',
#   'carried',
#   'happens',
#   'blocked',
#   'color',
#   'like',
#   'want',
#   'wish',
#   'connect',
#   'place',
#   'spent',
#   'love',
#   'often',
#   'great',
#   'careful',
#   'awesome',
#   'well',
#   'excercising',
#   'use'],
#  ('the', 'with'): ['picture',
#   'junction',
#   'unit',
#   'lens',
#   'instruction',
#   'cloth',
#   'gps',
#   'tweaking',
#   'speaker',
#   'earphone',
#   'one',
#   'speaker',
#   'system',
#   'telephone',
#   'remote',
#   'phone',
#   'pip',
#   'mouse',
#   'mouse',
#   'compatible',
#   'oven',
#   'station',
#   'picture',
#   'way',
#   'music',
#   'handset',
#   'control',
#   'album',
#   'problem',
#   'ysp',
#   'menu',
#   'same',
#   'dice',
#   'ease',
#   'problem',
#   'one',
#   'phone',
#   'sling',
#   'backpack',
#   'gps',
#   'stand',
#   'car',
#   'telephone',
#   'uplink',
#   'air',
#   'grave',
#   'kos',
#   'problem',
#   'locked',
#   'phone',
#   'ique',
#   'window',
#   'ease'],
#  ('picture', 'the'): ['with', 'jpegs', 'from', 'over', 'centered'],
#  ('with', 'memory'): ['the', 'sony', 'lesser', 'some', 'expandable'],
#  ('the', 'card'): ['memory',
#   'new',
#   'lexar',
#   'standard',
#   'memory',
#   'provided',
#   'quadro',
#   'gift',
#   'standard',
#   'display',
#   'adapter',
#   'credit'],
#  ('memory', 'recomend'): ['card'],
#  ('card', 'this'): ['recomend'],
#  ('recomend', 'product'): ['this'],
#  ('simple', 'there'): ['device', 'device'],
#  ('device', 'not'): ['there', 'there', 'will', 'ha'],
#  ('there', 'say'): ['not', 'not'],
#  ('not', 'about'): ['say',
#   'say',
#   'sure',
#   'thinking',
#   'know',
#   'great',
#   'sorry'],
#  ('say', 'other'): ['about', 'about'],
#  ('about', 'than'): ['other', 'other'],
#  ('other', 'doe'): ['than', 'than'],
#  ('than', 'the'): ['doe',
#   'doe',
#   'over',
#   'using',
#   'with',
#   'some',
#   'said',
#   'either',
#   'the',
#   'the',
#   'expected',
#   'with',
#   'with',
#   'most',
#   'movie',
#   'offset',
#   'red',
#   'with'],
#  ('doe', 'job'): ['the',
#   'the',
#   'great',
#   'the',
#   'it',
#   'excellent',
#   'good',
#   'fine',
#   'the',
#   'good',
#   'decent',
#   'the',
#   'the',
#   'great',
#   'nice'],
#  ('the', 'you'): ['job',
#   'disk',
#   'adapter',
#   'job',
#   'side',
#   'pouch',
#   'money',
#   'then',
#   'further',
#   'price',
#   'bose',
#   'presets',
#   'scientist',
#   'box',
#   'ipod',
#   'game',
#   'cost',
#   'radio',
#   'left',
#   'way',
#   'longer',
#   'fly',
#   'reason',
#   'product',
#   'base',
#   'fact',
#   'money',
#   'usa',
#   'contract',
#   'software',
#   'table',
#   'smoker',
#   'player',
#   'price',
#   'voice',
#   'range',
#   'picture',
#   'money',
#   'fact',
#   'back',
#   'remote',
#   'price',
#   'mouse',
#   'route',
#   'walking',
#   'price',
#   'dock',
#   'holiday',
#   'price',
#   'charger',
#   'country',
#   'and',
#   'manual',
#   'speaker',
#   'louder',
#   'ipod',
#   'book',
#   'product',
#   'price',
#   'money',
#   'end',
#   'accesories',
#   'car',
#   'money',
#   'price',
#   'best',
#   'airport',
#   'more',
#   'market',
#   'screen',
#   'right',
#   'price',
#   'way',
#   'documentation',
#   'part',
#   'contract',
#   'thing',
#   'ipod',
#   'internet',
#   'recording',
#   'player',
#   'list'],
#  ('job', 'should'): ['you', 'you'],
#  ('you', 'note'): ['should', 'should'],
#  ('should', 'that'): ['note',
#   'note',
#   'noted',
#   'know',
#   'know',
#   'know',
#   'say',
#   'know'],
#  ('note', 'the'): ['that',
#   'that',
#   'brian',
#   'that',
#   'some',
#   'twords',
#   'that',
#   'regarding'],
#  ('that', 'led'): ['the', 'the'],
#  ('the', 'the'): ['led',
#   'price',
#   'keyboard',
#   'video',
#   'video',
#   'quality',
#   'majority',
#   'led',
#   'remote',
#   'best',
#   'attachment',
#   'chasis',
#   'recording',
#   'hang',
#   'money',
#   'bedroom',
#   'feature',
#   'outside',
#   'find',
#   'ground',
#   'top',
#   'unit',
#   'daylight',
#   'weight',
#   'price',
#   'radio',
#   'roar',
#   'front',
#   'receiver',
#   'middle',
#   'bass',
#   'manual',
#   'tray',
#   'quality',
#   'click',
#   'durability',
#   'and',
#   'store',
#   'competition',
#   'handset',
#   'quality',
#   'ruggedness',
#   'way',
#   'piano',
#   'marketplace',
#   'way',
#   'ipod',
#   'volume',
#   'balance',
#   'pixel',
#   'middle',
#   'tension',
#   'tension',
#   'convenience',
#   'back',
#   'earbuds',
#   'westinghouse',
#   'picture',
#   'price',
#   'center',
#   'station',
#   'sony',
#   'wire',
#   'sound',
#   'scratch',
#   'way',
#   'best',
#   'over',
#   'quality',
#   'top',
#   'range',
#   'cushioning',
#   'are',
#   'office',
#   'office',
#   'accuracy',
#   'accuracy',
#   'receipt',
#   'dot',
#   'receipt',
#   'content',
#   'desk',
#   'back',
#   'ability',
#   'control',
#   'time',
#   'music',
#   'choice',
#   'burner',
#   'novice',
#   'song',
#   'speaker',
#   'closet',
#   'were',
#   'signal',
#   'exception',
#   'response',
#   'included',
#   'case',
#   'directory',
#   'weekend',
#   'box',
#   'way',
#   'height',
#   'bottom',
#   'desktop',
#   'bottom',
#   'firmware',
#   'same',
#   'over',
#   'are',
#   'seam',
#   'back',
#   'selection',
#   'floor',
#   'glowing',
#   'bottom',
#   'resolution',
#   'fact',
#   'product',
#   'setting',
#   'out',
#   'pad',
#   'mouse',
#   'range',
#   'keyboard',
#   'mouse',
#   'thinness',
#   'entrance',
#   'weight',
#   'car',
#   'tread',
#   'beat',
#   'quality',
#   'concept',
#   'price',
#   'foot',
#   'surface',
#   'point',
#   'quality',
#   'nano',
#   'top',
#   'dock',
#   'belkin',
#   'end',
#   'time',
#   'use',
#   'card',
#   'feature',
#   'case',
#   'wa',
#   'complexity',
#   'king',
#   'top',
#   'side',
#   'edge',
#   'holder',
#   'bottom',
#   'quality',
#   'rest',
#   'inconsistency',
#   'plague',
#   'from',
#   'way',
#   'front',
#   'weekend',
#   'protects',
#   'other',
#   'madness',
#   'world',
#   'button',
#   'light',
#   'that',
#   'screen',
#   'job',
#   'hulk',
#   'end',
#   'way',
#   'ipod',
#   'wall',
#   'phone',
#   'button',
#   'bottom',
#   'notch',
#   'bottom',
#   'cache',
#   'sensitivity',
#   'lack',
#   'enable',
#   'accuracy',
#   'payment',
#   'ball',
#   'for',
#   'radio',
#   'signal',
#   'front',
#   'others',
#   'dolby',
#   'reservoir',
#   'option',
#   'buckle',
#   'shuffle',
#   'icing',
#   'cake',
#   'lot',
#   'way',
#   'recording',
#   'disk',
#   'monster',
#   'successor',
#   'than',
#   'news',
#   'base',
#   'ipod',
#   'cup',
#   'ipod',
#   'front',
#   'best',
#   'itrip',
#   'number',
#   'air',
#   'cable',
#   'back',
#   'drive',
#   'dialogue',
#   'airport',
#   'software',
#   'design',
#   'hinge',
#   'dark',
#   'money',
#   'house',
#   'part',
#   'design',
#   'top',
#   'heat',
#   'mode',
#   'set',
#   'comfort',
#   'also',
#   'hold',
#   'overture',
#   'mechanic',
#   'back',
#   'sturdiness',
#   'purpose',
#   'apc',
#   'back',
#   'end',
#   'car',
#   'software',
#   'product',
#   'center',
#   'screen',
#   'phone',
#   'side',
#   'phone',
#   'speaker',
#   'face',
#   'back',
#   'white',
#   'button',
#   'back',
#   'image',
#   'adjustment',
#   'firmware',
#   'latest',
#   'possibility',
#   'outside',
#   'top',
#   'price',
#   'pouch',
#   'mount',
#   'quality',
#   'grip',
#   'card',
#   'job',
#   'best',
#   'traffic',
#   'and',
#   'size',
#   'receiver',
#   'place',
#   'mouse',
#   'crispness',
#   'garmin',
#   'cobra',
#   'unit',
#   'size',
#   'soon',
#   'quality',
#   'rebate',
#   'bass',
#   'raio',
#   'usb',
#   'installation',
#   'network',
#   'hand',
#   'ear',
#   'club',
#   'force',
#   'shape',
#   'convenience',
#   'wireless',
#   'signal',
#   'during',
#   'adapter',
#   'micro',
#   'recognized',
#   'bridge',
#   'reflector',
#   'setting',
#   'setting',
#   'feature',
#   'mir',
#   'handset',
#   'ha',
#   'power',
#   'tape',
#   'right',
#   'back',
#   'laptop',
#   'side',
#   'printer',
#   'front',
#   'silicone',
#   'case',
#   'iskin',
#   'bullet',
#   'price',
#   'picture',
#   'downloaded',
#   'map',
#   'hang',
#   'pod',
#   'week',
#   'beginning',
#   'song',
#   'most',
#   'side',
#   'quality',
#   'guitar',
#   'past',
#   'people',
#   'person',
#   'key',
#   'button',
#   'top',
#   'road'],
#  ('led', 'device'): ['the', 'the'],
#  ('the', 'remain'): ['device', 'device'],
#  ('device', 'lit'): ['remain', 'remain'],
#  ('remain', 'long'): ['lit', 'lit'],
#  ('lit', 'the'): ['long', 'long'],
#  ('long', 'device'): ['the', 'the'],
#  ('the', 'plugged'): ['device', 'device'],
#  ('device', 'into'): ['plugged', 'plugged', 'plug'],
#  ('plugged', 'your'): ['into', 'into'],
#  ('into', 'and'): ['your', 'your', 'modem', 'three', 'pocket', 'the'],
#  ('your', 'the'): ['and',
#   'and',
#   'mount',
#   'radio',
#   'choice',
#   'budget',
#   'hand',
#   'hand',
#   'image',
#   'finger',
#   'gizmo',
#   'sound',
#   'ear',
#   'head'],
#  ('and', 'powered'): ['the', 'the'],
#  ('the', 'they'): ['powered',
#   'powered',
#   'bass',
#   'pressure',
#   'photographer',
#   'cinema',
#   'product',
#   'price',
#   'price',
#   'room',
#   'that',
#   'but',
#   'aircraft',
#   'tunedok',
#   'product',
#   'road',
#   'unit',
#   'good',
#   'industry',
#   'money',
#   'gym',
#   'cord',
#   'greatest'],
#  ('powered', 'glow'): ['they', 'they'],
#  ('they', 'bright'): ['glow', 'glow'],
#  ('glow', 'blue'): ['bright', 'bright'],
#  ('wa', 'about'): ['thinking',
#   'skeptical',
#   'apprehensive',
#   'paranoid',
#   'worried'],
#  ('thinking', 'buying'): ['about'],
#  ('about', 'card'): ['buying'],
#  ('buying', 'but'): ['card'],
#  ('card', 'after'): ['but'],
#  ('but', 'reading'): ['after'],
#  ('after', 'one'): ['reading', 'maybe'],
#  ('reading', 'the'): ['one', 'all', 'some', 'some'],
#  ('one', 'review'): ['the'],
#  ('review', 'two'): ['bought'],
#  ('two', 'just'): ['card', 'them', 'movie'],
#  ('card', 'case'): ['just'],
#  ('just', 'that'): ['case', 'get', 'consider'],
#  ('case', 'something'): ['that'],
#  ('that', 'went'): ['something'],
#  ('something', 'wrong'): ['went'],
#  ('went', 'which'): ['wrong'],
#  ('wrong', 'made'): ['which'],
#  ('which', 'lot'): ['made', 'sound'],
#  ('made', 'sense'): ['lot'],
#  ('lot', 'please'): ['sense'],
#  ('have', 'been'): ['always', 'always', 'finally', 'never', 'never', 'never'],
#  ('always', 'very'): ['been'],
#  ('been', 'pleased'): ['very', 'very', 'very', 'quite'],
#  ('pleased', 'the'): ['with',
#   'with',
#   'with',
#   'with',
#   'with',
#   'with',
#   'with',
#   'with',
#   'with'],
#  ('with', 'sandisk'): ['the'],
#  ('the', 'product'): ['sandisk',
#   'nulooq',
#   'skipdoctor',
#   'best',
#   'best',
#   'covered',
#   'manufacturer',
#   'same',
#   'cheaper',
#   'portable',
#   'covered',
#   'perfect'],
#  ('sandisk', 'would'): ['product'],
#  ('product', 'highly'): ['would', 'would'],
#  ('would', 'recommend'): ['highly',
#   'highly',
#   'definitely',
#   'definitely',
#   'highly',
#   'definitely',
#   'highly',
#   'highly',
#   'highly',
#   'highly',
#   'not',
#   'not',
#   'highly',
#   'definately',
#   'highly',
#   'highly',
#   'highly',
#   'highly'],
#  ('highly', 'them'): ['recommend', 'recommand', 'recommend', 'recommend'],
#  ('these', 'are'): ['earphone',
#   'case',
#   'battery',
#   'earphone',
#   'battery',
#   'headphone',
#   'headphone',
#   'earphone',
#   'headphone',
#   'thing',
#   'verbatims',
#   'verbatim',
#   'cable',
#   'cable',
#   'cable',
#   'dvd',
#   'speaker',
#   'headphone',
#   'figure',
#   'card',
#   'cable',
#   'frequency',
#   'they',
#   'number',
#   'heaphone',
#   'headphone',
#   'piece',
#   'cable',
#   'place',
#   'speaker',
#   'speaker',
#   'speaker',
#   'speaker',
#   'cable',
#   'speaker',
#   'earphone',
#   'that',
#   'earbuds'],
#  ('earphone', 'great'): ['are', 'were'],
#  ('are', 'quality'): ['great', 'top', 'acceptable', 'real', 'excellent'],
#  ('great', 'the'): ['quality',
#   'and',
#   'not',
#   'like',
#   'example',
#   'because',
#   'like',
#   'and',
#   'value',
#   'relief',
#   'for',
#   'for',
#   'and',
#   'joy',
#   'with',
#   'love'],
#  ('quality', 'sound'): ['the', 'the', 'the', 'the', 'the'],
#  ('the', 'good'): ['sound',
#   'product',
#   'price',
#   'phone',
#   'destruction',
#   'midrange',
#   'keyboard',
#   'case',
#   'ha',
#   'design',
#   'camers',
#   'very',
#   'had',
#   'itrip',
#   'sound',
#   'light',
#   'price',
#   'sound'],
#  ('sound', 'and'): ['good',
#   'effect',
#   'head',
#   'high',
#   'boomier',
#   'great',
#   'loud',
#   'range',
#   'card',
#   'quality',
#   'designation',
#   'nasal',
#   'reproduction',
#   'out',
#   'decent',
#   'fuller',
#   'better',
#   'directly',
#   'great',
#   'microphone',
#   'quality',
#   'dvd',
#   'good'],
#  ('good', 'they'): ['and'],
#  ('and', 'fit'): ['they',
#   'seem',
#   'perfect',
#   'actually',
#   'can',
#   'comfortable',
#   'they',
#   'all',
#   'this',
#   'will',
#   'easily',
#   'perfect'],
#  ('they', 'comfortably'): ['fit', 'fit', 'are'],
#  ('fit', 'the'): ['comfortably',
#   'into',
#   'for',
#   'below',
#   'dvd',
#   'all',
#   'under',
#   'into'],
#  ('comfortably', 'ear'): ['the', 'the'],
#  ('the', 'once'): ['ear',
#   'screen',
#   'store',
#   'battery',
#   'screen',
#   'clickers',
#   'message',
#   'network',
#   'expander',
#   'case'],
#  ('ear', 'you'): ['once'],
#  ('once', 'get'): ['you', 'you', 'they', 'you', 'you'],
#  ('you', 'used'): ['get', 'get', 'are', 'are', 'get', 'have', 'are'],
#  ('get', 'them'): ['used', 'from'],
#  ('used', 'two'): ['them'],
#  ('them', 'minus'): ['two'],
#  ('two', 'make'): ['minus'],
#  ('minus', 'them'): ['make'],
#  ('make', 'only'): ['them'],
#  ('them', 'out'): ['only', 'slipping', 'print', 'and'],
#  ('only', 'star'): ['out'],
#  ('out', 'first'): ['star'],
#  ('star', 'the'): ['first',
#   'for',
#   'because',
#   'also',
#   'for',
#   'due',
#   'for',
#   'that'],
#  ('first', 'customer'): ['the'],
#  ('the', 'support'): ['customer', 'wrist', 'product', 'linux', 'harmony'],
#  ('customer', 'weak'): ['support'],
#  ('support', 'there'): ['weak'],
#  ('weak', 'supposed'): ['there'],
#  ('there', 'website'): ['supposed'],
#  ('supposed', 'for'): ['website'],
#  ('website', 'the'): ['for', 'recently'],
#  ('the', 'for'): ['product',
#   'commercial',
#   'firmware',
#   'one',
#   'movie',
#   'budget',
#   'telephone',
#   'cable',
#   'unit',
#   'file',
#   'sennheiser',
#   'isight',
#   'stitching',
#   'subwoofer',
#   'adapter',
#   'need',
#   'apu',
#   'option',
#   'garage',
#   'button',
#   'phone',
#   'and',
#   'model',
#   'same',
#   'keyboard',
#   'back',
#   'ideal',
#   'market',
#   'charger',
#   'driver',
#   'battery',
#   'computer',
#   'manufacturer',
#   'paid',
#   'landscape',
#   'squeezebox',
#   'number',
#   'default',
#   'web',
#   'price',
#   'money',
#   'bottom',
#   'extra',
#   'demand',
#   'bag',
#   'safest',
#   'pack',
#   'need',
#   'laptop',
#   'one',
#   'purpose',
#   'price',
#   'hole',
#   'base',
#   'camera',
#   'camera',
#   'reason',
#   'price',
#   'headphone',
#   'tunejuice',
#   'other',
#   'manufacturer',
#   'market',
#   'knob',
#   'port',
#   'product',
#   'samsung',
#   'replacement',
#   'market',
#   'software',
#   'keypad',
#   'swicth',
#   'original',
#   'wall',
#   'best',
#   'time',
#   'cap'],
#  ('product', 'customer'): ['for'],
#  ('for', 'support'): ['customer'],
#  ('customer', 'and'): ['support'],
#  ('support', 'replacement'): ['and'],
#  ('and', 'part'): ['replacement'],
#  ('replacement', 'but'): ['part', 'cap', 'knob'],
#  ('part', 'altec'): ['but'],
#  ('but', 'lansing'): ['altec'],
#  ('altec', 'his'): ['lansing'],
#  ('lansing', 'linked'): ['his'],
#  ('his', 'seemingly'): ['linked'],
#  ('linked', 'unrelated'): ['seemingly'],
#  ('seemingly', 'product'): ['unrelated'],
#  ('unrelated', 'second'): ['product'],
# ...
#   'much',
#   'hiss',
#   'ipod',
#   'clickwheel',
#   'printer',
#   'list',
#   'market'],
#  ('time', 'excelent'): ['but'],
#  ('but', 'pen'): ['excelent'],
#  ('excelent', 'drive'): ['pen', 'hard'],
#  ('pen', 'small'): ['drive'],
#  ('drive', 'and'): ['small', 'fast', 'far'],
#  ('small', 'with'): ['and', 'came', 'ear', 'sleek', 'problem'],
#  ('and', 'good'): ['with',
#   'imaging',
#   'have',
#   'that',
#   'sound',
#   'your',
#   'for',
#   'fine',
#   'feel',
#   'know',
#   'not',
#   'you',
#   'had',
#   'expect',
#   'feature',
#   'very',
#   'listen',
#   'offer'],
#  ('with', 'style'): ['good'],
#  ('work', 'really'): ['great', 'and'],
#  ('great', 'like'): ['really', 'just'],
#  ('really', 'there'): ['like'],
#  ('like', 'one'): ['there', 'the', 'this'],
#  ('there', 'small'): ['one', 'are'],
#  ('one', 'problem'): ['small', 'major'],
#  ('small', 'though'): ['problem', 'room'],
#  ('problem', 'the'): ['though',
#   'with',
#   'yet',
#   'with',
#   'installing',
#   'and',
#   'with',
#   'connecting',
#   'both',
#   'with',
#   'first',
#   'with',
#   'with',
#   'with',
#   'ever',
#   'since',
#   'than',
#   'whatsoever',
#   'with',
#   'with',
#   'with',
#   'keeping',
#   'with',
#   'and',
#   'with',
#   'think',
#   'with',
#   'from',
#   'carrying',
#   'from',
#   'far',
#   'with',
#   'hitting',
#   'with'],
#  ('though', 'lid'): ['the'],
#  ('the', 'really'): ['lid',
#   'job',
#   'dial',
#   'price',
#   'screen',
#   'reason',
#   'neighborhood',
#   'result',
#   'paper',
#   'would',
#   'screen',
#   'neck',
#   'range',
#   'this',
#   'price'],
#  ('lid', 'hard'): ['really'],
#  ('really', 'take'): ['hard'],
#  ('hard', 'off'): ['take'],
#  ('take', 'had'): ['off'],
#  ('off', 'now'): ['had'],
#  ('now', 'about'): ['for'],
#  ('about', 'and'): ['month', 'year', 'buck', 'month', 'month'],
#  ('month', 'have'): ['and', 'flawlessly', 'and', 'since', 'currently'],
#  ('and', 'gotten'): ['have'],
#  ('have', 'lot'): ['gotten'],
#  ('gotten', 'use'): ['lot', 'extensive'],
#  ('lot', 'out'): ['use', 'use'],
#  ('use', 'and'): ['out',
#   'mac',
#   'backlight',
#   'small',
#   'ink',
#   'this',
#   'water',
#   'video',
#   'headset',
#   'everyday'],
#  ('out', 'ha'): ['and'],
#  ('and', 'loosened'): ['ha'],
#  ('ha', 'little'): ['loosened'],
#  ('loosened', 'but'): ['little'],
#  ('little', 'not'): ['but', 'difficult'],
#  ('but', 'much'): ['not', 'it', 'not'],
#  ('not', 'there'): ['much', 'robust', 'complaining'],
#  ('much', 'ha'): ['there', 'and'],
#  ('there', 'got'): ['ha'],
#  ('ha', 'way'): ['got'],
#  ('got', 'make'): ['way'],
#  ('way', 'lid'): ['make'],
#  ('make', 'that'): ['lid', 'sure', 'sure', 'realize', 'sure', 'sure'],
#  ('lid', 'stay'): ['that'],
#  ('that', 'but'): ['stay',
#   'brought',
#   'promised',
#   'own',
#   'impressed',
#   'category',
#   'recording',
#   'mean',
#   'much'],
#  ('stay', 'isn'): ['but'],
#  ('but', 'quite'): ['isn', 'actually'],
#  ('isn', 'hard'): ['quite'],
#  ('quite', 'remove'): ['hard'],
#  ('hard', 'when'): ['remove'],
#  ('remove', 'person'): ['when'],
#  ('when', 'want'): ['person'],
#  ('person', 'use'): ['want'],
#  ('want', 'appreciate'): ['use'],
#  ('use', 'being'): ['appreciate'],
#  ('appreciate', 'provided'): ['being'],
#  ('being', 'with'): ['provided', 'plane'],
#  ('provided', 'forum'): ['with'],
#  ('with', 'voice'): ['forum'],
#  ('forum', 'opinion'): ['voice'],
#  ('work', 'with'): ['well',
#   'great',
#   'fine',
#   'great',
#   'well',
#   'great',
#   'okay',
#   'flawlessly',
#   'fine',
#   'well',
#   'great',
#   'beautifully',
#   'great',
#   'great',
#   'great',
#   'flawlessly',
#   'well'],
#  ('well', 'without'): ['with'],
#  ('with', 'software'): ['without',
#   'the',
#   'quickcam',
#   'the',
#   'the',
#   'this',
#   'the'],
#  ('without', 'installed'): ['software'],
#  ('software', 'good'): ['installed'],
#  ('installed', 'for'): ['good'],
#  ('good', 'home'): ['for'],
#  ('for', 'use'): ['home',
#   'scrolling',
#   'most',
#   'kid',
#   'phone',
#   'personal',
#   'car',
#   'office',
#   'everyday',
#   'home',
#   'onstage'],
#  ('home', 'and'): ['use', 'office', 'say', 'audio', 'business'],
#  ('use', 'school'): ['and'],
#  ('and', 'traveling'): ['school'],
#  ('this', 'work'): ['technically',
#   'wouldn',
#   'keyboard',
#   'either',
#   'product',
#   'thing',
#   'mouse',
#   'thing',
#   'paper',
#   'amplifier',
#   'unit',
#   'gps',
#   'stand',
#   'stereo',
#   'product'],
#  ('technically', 'well'): ['work'],
#  ('work', 'finding'): ['well'],
#  ('well', 'learning'): ['finding'],
#  ('finding', 'use'): ['learning'],
#  ('learning', 'difficult'): ['use'],
#  ('use', 'really'): ['difficult', 'not'],
#  ('difficult', 'wish'): ['really'],
#  ('really', 'had'): ['wish', 'bad'],
#  ('wish', 'spent'): ['had'],
#  ('had', 'little'): ['spent'],
#  ('spent', 'more'): ['little'],
#  ('little', 'and'): ['more',
#   'expectation',
#   'small',
#   'detail',
#   'high',
#   'small',
#   'subwoofer',
#   'slower',
#   'soap',
#   'flimsy',
#   'space',
#   'machine',
#   'irritation'],
#  ('more', 'gotten'): ['and'],
#  ('and', 'bigger'): ['gotten'],
#  ('gotten', 'one'): ['bigger'],
#  ('bigger', 'lot'): ['one'],
#  ('one', 'smaller'): ['lot'],
#  ('lot', 'than'): ['smaller', 'cheaper'],
#  ('smaller', 'thought'): ['than'],
#  ('than', 'would'): ['thought', 'you'],
#  ('thought', 'and'): ['would'],
#  ('would', 'would'): ['and'],
#  ('and', 'alot'): ['would'],
#  ('would', 'easier'): ['alot'],
#  ('alot', 'wa'): ['easier'],
#  ('easier', 'bigger'): ['wa'],
#  ('wa', 'purchasing'): ['considering', 'worth'],
#  ('considering', 'tablet'): ['purchasing'],
#  ('purchasing', 'and'): ['tablet'],
#  ('tablet', 'wacom'): ['and'],
#  ('and', 'wa'): ['wacom',
#   'the',
#   'this',
#   'connection',
#   'connected',
#   'then',
#   'done',
#   'that',
#   'that',
#   'thought',
#   'though',
#   'detail',
#   'there',
#   'that',
#   'that',
#   'price',
#   'everything',
#   'since',
#   'fitting',
#   'suddenly',
#   'bed',
#   'accurate',
#   'figured',
#   'sub',
#   'this',
#   'believe'],
#  ('wacom', 'consistantly'): ['wa'],
#  ('wa', 'recommended'): ['consistantly'],
#  ('consistantly', 'wa'): ['recommended'],
#  ('recommended', 'originally'): ['wa'],
#  ('wa', 'hesitant'): ['originally', 'little', 'little'],
#  ('originally', 'buy'): ['hesitant'],
#  ('hesitant', 'the'): ['buy'],
#  ('buy', 'graphire'): ['the'],
#  ('the', 'line'): ['graphire',
#   'top',
#   'intuos',
#   'bass',
#   'speaker',
#   'flight',
#   'ringing',
#   'dirty',
#   'cable',
#   'sound',
#   'manual'],
#  ('graphire', 'because'): ['line'],
#  ('line', 'didnt'): ['because'],
#  ('because', 'think'): ['didnt', 'don'],
#  ('didnt', 'would'): ['think'],
#  ('think', 'very'): ['would'],
#  ('would', 'good'): ['very', 'make'],
#  ('very', 'for'): ['good',
#   'good',
#   'good',
#   'clear',
#   'good',
#   'helpful',
#   'convenient',
#   'important',
#   'good'],
#  ('good', 'drawing'): ['for'],
#  ('for', 'compared'): ['drawing'],
#  ('drawing', 'the'): ['compared'],
#  ('compared', 'top'): ['the'],
#  ('top', 'the'): ['line', 'performance', 'half'],
#  ('line', 'intuos'): ['the'],
#  ('intuos', 'wa'): ['line'],
#  ('line', 'pleasantly'): ['wa'],
#  ('wa', 'surprised'): ['pleasantly', 'pleasantly', 'very', 'pleasantly'],
#  ('pleasantly', 'proven'): ['surprised'],
#  ('surprised', 'wrong'): ['proven'],
#  ('proven', 'installing'): ['wrong'],
#  ('wrong', 'driver'): ['installing'],
#  ('installing', 'wa'): ['driver'],
#  ('driver', 'piece'): ['wa'],
#  ('wa', 'cake'): ['piece', 'piece'],
#  ('piece', 'and'): ['cake', 'equipment'],
#  ('cake', 'began'): ['and'],
#  ('and', 'drawing'): ['began'],
#  ('began', 'away'): ['drawing'],
#  ('drawing', 'minute'): ['away'],
#  ('away', 'very'): ['minute'],
#  ('minute', 'responsive'): ['very'],
#  ('very', 'and'): ['responsive',
#   'flimsy',
#   'punchy',
#   'good',
#   'lowest',
#   'bright',
#   'linear',
#   'stylish',
#   'well',
#   'clear',
#   'comfortable',
#   'minimal',
#   'handy',
#   'clear',
#   'crisp',
#   'comfortable',
#   'good',
#   'comfortable',
#   'handy',
#   'obvious',
#   'heavy',
#   'convient',
#   'inexpensive',
#   'satisfied',
#   'friendly',
#   'poor',
#   'well',
#   'sensible',
#   'powerful',
#   'easy',
#   'good',
#   'comfortable',
#   'modern',
#   'good',
#   'good',
#   'easily',
#   'heavy',
#   'thick',
#   'useful',
#   'bright',
#   'good',
#   'intuitive',
#   'sophisticated',
#   'solid',
#   'firmly'],
#  ('responsive', 'work'): ['and'],
#  ('and', 'with'): ['work',
#   'actually',
#   'mac',
#   'come',
#   'travel',
#   'one',
#   'connect',
#   'replied',
#   'providing',
#   'heat',
#   'especially',
#   'expand',
#   'experience',
#   'keyboard',
#   'well',
#   'went',
#   'problem',
#   'off',
#   'happy',
#   'caller',
#   'are',
#   'get',
#   'laptop',
#   'also',
#   'agree',
#   'problem',
#   'down',
#   'compaq'],
#  ('work', 'all'): ['with', 'for', 'all', 'with', 'with', 'for'],
#  ('with', 'drawing'): ['all'],
#  ('all', 'program'): ['drawing'],
#  ('drawing', 'paintshop'): ['program'],
#  ('program', 'pro'): ['paintshop'],
#  ('paintshop', 'painter'): ['pro'],
#  ('pro', 'photoshop'): ['painter'],
#  ('painter', 'the'): ['photoshop'],
#  ('photoshop', 'mouse'): ['the'],
#  ('the', 'pretty'): ['mouse',
#   'lcd',
#   'bass',
#   'battery',
#   'sound',
#   'price',
#   'shower'],
#  ('mouse', 'useless'): ['pretty'],
#  ('pretty', 'however'): ['useless'],
#  ('useless', 'and'): ['however'],
#  ('however', 'would'): ['and'],
#  ('and', 'have'): ['would',
#   'wouldn',
#   'far',
#   'never',
#   'now',
#   'don',
#   'still',
#   'typically',
#   'you',
#   'model',
#   'you',
#   'didnt',
#   'also',
#   'great',
#   'not',
#   'would',
#   'easy',
#   'treble',
#   'designed',
#   'love',
#   'now',
#   'unbiased',
#   'not',
#   'crisp',
#   'couldn',
#   'not',
#   'trust',
#   'they',
#   'not',
#   'durable',
#   'don',
#   'would',
#   'you',
#   'dont',
#   'still',
#   'far',
#   'must',
#   'scan',
#   'all',
#   'reliability',
#   'sound',
#   'far',
#   'still',
#   'you',
#   'you',
#   'doesn',
#   'far'],
#  ('would', 'preferred'): ['have'],
#  ('have', 'they'): ['preferred', 'ooommphhhh', 'read', 'read'],
#  ('preferred', 'had'): ['they'],
#  ('they', 'included'): ['had'],
#  ('had', 'some'): ['included', 'acquire', 'find'],
#  ('included', 'extra'): ['some'],
#  ('some', 'pen'): ['extra'],
#  ('extra', 'tip'): ['pen'],
#  ('pen', 'instead'): ['tip'],
#  ('tip', 'they'): ['instead'],
#  ('instead', 'seem'): ['they'],
#  ('they', 'wear'): ['seem'],
#  ('seem', 'out'): ['wear'],
#  ('wear', 'though'): ['out'],
#  ('out', 'press'): ['though'],
#  ('though', 'pretty'): ['press'],
#  ('press', 'hard'): ['pretty', 'too'],
#  ('pretty', 'other'): ['hard'],
#  ('hard', 'than'): ['other'],
#  ('other', 'that'): ['than',
#   'than',
#   'earphone',
#   'review',
#   'cable',
#   'lcd',
#   'phone',
#   'data',
#   'than',
#   'thing',
#   'complaint',
#   'product',
#   'than',
#   'than',
#   'model',
#   'then',
#   'application',
#   'than',
#   'headphone',
#   'than',
#   'than'],
#  ('than', 'it'): ['that'],
#  ('that', 'amazing'): ['it'],
#  ('it', 'product'): ['amazing'],
#  ('battery', 'camera'): ['for'],
#  ('for', 'they'): ['camera',
#   'and',
#   'racing',
#   'but',
#   'while',
#   'psp',
#   'which',
#   'under',
#   'but',
#   'logitech',
#   'this',
#   'while'],
#  ('camera', 'charge'): ['they'],
#  ('they', 'quickly'): ['charge'],
#  ('charge', 'and'): ['quickly', 'quickly', 'ipod', 'powerbook'],
#  ('quickly', 'handy'): ['and'],
#  ('and', 'keep'): ['handy', 'agenda', 'can'],
#  ('handy', 'the'): ['keep', 'and', 'considering'],
#  ('keep', 'extra'): ['the'],
#  ('the', 'spare'): ['extra'],
#  ('extra', 'the'): ['spare', 'like', 'caution', 'speed', 'bit', 'for', 'use'],
#  ('spare', 'charger'): ['the', 'battery'],
#  ('charger', 'with'): ['and', 'work'],
#  ('and', 'all'): ['with',
#   'almost',
#   'record',
#   'all',
#   'seamless',
#   'best',
#   'treble',
#   'had',
#   'used',
#   'metal',
#   'that',
#   'like',
#   'such',
#   'fire',
#   'program',
#   'model',
#   'listened',
#   'powerdvd',
#   'had',
#   'spent',
#   'ipod',
#   'had'],
#  ('with', 'the'): ['all',
#   'hassle',
#   'happiness',
#   'theirs',
#   'tough',
#   'them',
#   'some',
#   'anyhow',
#   'problem',
#   'some',
#   'button',
#   'just',
#   'bose',
#   'both',
#   'woofer',
#   'problem',
#   'either',
#   'either',
#   'usb',
#   'choice',
#   'them',
#   'duracells',
#   'all',
#   'purchase',
#   'camera',
#   'which',
#   'hassle',
#   'either',
#   'either',
#   'most',
#   'the',
#   'that',
#   'all',
#   'one',
#   'all',
#   'discount',
#   'hdmi',
#   'either',
#   'maybe',
#   'all',
#   'just',
#   'alarm',
#   'video',
#   'most',
#   'wish',
#   'signal',
#   'since',
#   'reading'],
#  ('all', 'time'): ['the', 'the', 'the', 'the', 'the', 'the', 'the', 'the'],
#  ('the', 'just'): ['time',
#   'software',
#   'installed',
#   'screen',
#   'size',
#   'earphone',
#   'range',
#   'price',
#   'mouse',
#   'mouse',
#   'had',
#   'ipod',
#   'tunecast',
#   'probably',
#   'ear',
#   'usb',
#   'rest',
#   'player',
#   'price',
#   'color',
#   'operation',
#   'player'],
#  ('time', 'case'): ['just'],
#  ('bought', 'nulooq'): ['the'],
#  ('nulooq', 'few'): ['product'],
#  ('product', 'week'): ['few', 'couple'],
#  ('few', 'ago'): ['week',
#   'month',
#   'week',
#   'day',
#   'year',
#   'hour',
#   'day',
#   'day',
#   'year',
#   'week'],
#  ('week', 'with'): ['ago'],
#  ('ago', 'little'): ['with'],
#  ('with', 'expectation'): ['little'],
#  ('expectation', 'actually'): ['and'],
#  ('actually', 'some'): ['with', 'dropped'],
#  ('with', 'doubt'): ['some'],
#  ('some', 'anything'): ['doubt'],
#  ('doubt', 'for'): ['anything'],
#  ('anything', 'keyboard'): ['for'],
#  ('for', 'junkie'): ['keyboard'],
#  ('keyboard', 'the'): ['junkie', 'some', 'one', 'essential'],
#  ('junkie', 'product'): ['the'],
#  ('the', 'description'): ['product', 'product', 'product'],
#  ('product', 'wa'): ['description'],
#  ('description', 'bit'): ['wa'],
#  ('wa', 'confusing'): ['bit'],
#  ('bit', 'seems'): ['confusing'],
#  ('confusing', 'like'): ['seems'],
#  ('seems', 'doe'): ['like'],
#  ('like', 'lot'): ['doe', 'take'],
#  ('doe', 'but'): ['lot'],
#  ('lot', 'what'): ['but'],
#  ('but', 'surprise'): ['what'],
#  ('what', 'just'): ['surprise'],
#  ('surprise', 'adjusting'): ['just'],
#  ('adjusting', 'brush'): ['the'],
#  ('the', 'size'): ['brush',
#   'perfect',
#   'specific',
#   'small',
#   'largest',
#   'right',
#   'added',
#   'small',
#   'best',
#   'same',
#   'perfect',
#   'file'],
#  ('brush', 'using'): ['size'],
#  ('size', 'the'): ['using'],
#  ('using', 'ipod'): ['the'],
#  ('the', 'like'): ['ipod',
#   'product',
#   'new',
#   'lyra',
#   'con',
#   'sound',
#   'headphone',
#   'cable',
#   'thing',
#   'dock',
#   'song',
#   'tunedok',
#   'three',
#   'thing',
#   'bank',
#   'street',
#   'info',
#   'keyboard'],
#  ('ipod', 'scroll'): ['like'],
#  ('like', 'disc'): ['scroll'],
#  ('scroll', 'the'): ['disc', 'wheel', 'through', 'through'],
#  ('disc', 'device'): ['the'],
#  ('the', 'worth'): ['device', 'definitely', 'extra', 'drive'],
#  ('device', 'the'): ['worth', 'and', 'wa', 'for', 'great', 'but', 'pressing'],
#  ('worth', 'price'): ['the', 'the', 'the', 'the'],
#  ('price', 'pop'): ['the'],
#  ('the', 'menu'): ['pop',
#   'screen',
#   'main',
#   'ipod',
#   'interface',
#   'screen',
#   'screen'],
#  ('pop', 'thing'): ['menu'],
#  ('menu', 'cool'): ['thing'],
#  ('thing', 'don'): ['cool'],
#  ('cool', 'use'): ['don', 'don'],
#  ('don', 'much'): ['use',
#   'take',
#   'care',
#   'have',
#   'use',
#   'have',
#   'have',
#   'use'],
#  ('use', 'for'): ['much',
#   'usb',
#   'microsoft',
#   'them',
#   'this',
#   'backup',
#   'them',
#   'the',
#   'them',
#   'these',
#   'even',
#   'pro',
#   'last',
#   'this',
#   'last'],
#  ('much', 'putting'): ['for'],
#  ('for', 'tool'): ['putting'],
#  ('putting', 'but'): ['tool'],
#  ('tool', 'putting'): ['but'],
#  ('but', 'file'): ['putting'],
#  ('putting', 'and'): ['file'],
#  ('file', 'folder'): ['and', 'and'],
#  ('and', 'into'): ['folder',
#   'slide',
#   'video',
#   'install',
#   'then',
#   'plugged',
#   'load'],
#  ('folder', 'that'): ['into'],
#  ('into', 'menu'): ['that'],
#  ('that', 'keep'): ['menu', 'can', 'help'],
#  ('menu', 'thing'): ['keep'],
#  ('keep', 'one'): ['thing'],
#  ('thing', 'place'): ['one'],
#  ('one', 'guess'): ['place'],
#  ('place', 'the'): ['guess',
#   'find',
#   'for',
#   'for',
#   'for',
#   'are',
#   'top',
#   'for',
#   'back',
#   'all',
#   'isn',
#   'isnt'],
#  ('guess', 'product'): ['the'],
#  ('the', 'also'): ['product',
#   'case',
#   'scratch',
#   'output',
#   'profile',
#   'unit',
#   'cable',
#   'picturemate',
#   'phone',
#   'keyboard',
#   'computer',
#   'software',
#   'eclipse',
#   'cabinet',
#   'desk',
#   'headset',
#   'player',
#   'phone',
#   'case',
#   'ipod',
#   'treble',
#   'screen',
#   'price',
#   'bluetooth',
#   'phone',
#   'pad'],
#  ('product', 'let'): ['also'],
#  ('also', 'you'): ['let', 'give', 'help'],
#  ('let', 'pan'): ['you'],
#  ('you', 'and'): ['pan',
#   'store',
#   'and',
#   'want',
#   'hang',
#   'got',
#   'off',
#   'like',
#   'can',
#   'going'],
#  ('pan', 'zoom'): ['and', 'and'],
#  ('and', 'around'): ['zoom',
#   'zoom',
#   'shopping',
#   'listen',
#   'turn',
#   'knocked',
#   'wear'],
#  ...}

# %%
M[:2], pi[:1]
# Out:
# (array([[7.04046861e-05, 2.76127179e-02, 3.36111972e-02, 4.38621195e-02,
#          4.22428117e-04, 8.73018108e-03, 2.05018446e-02, 1.08704835e-02,
#          4.75090822e-02, 2.95699682e-04, 1.45456082e-02, 1.10633924e-01,
#          2.53034442e-02, 2.09721479e-01, 2.11214058e-04, 2.34306795e-02,
#          7.04046861e-05, 1.08395055e-01, 9.77076234e-02, 1.42217466e-01,
#          7.92756766e-03, 2.33602749e-02, 1.04198935e-02, 4.50589991e-04,
#          2.94854826e-02, 2.63313526e-03],
#         [6.00292826e-02, 2.66089503e-02, 6.36577758e-05, 5.72919982e-04,
#          2.54949392e-01, 6.36577758e-05, 1.27315552e-04, 4.45604431e-04,
#          3.79400344e-02, 5.47456872e-03, 6.36577758e-05, 1.20567827e-01,
#          8.91208861e-04, 1.27315552e-04, 1.52333057e-01, 6.36577758e-05,
#          6.36577758e-05, 5.88197848e-02, 1.89063594e-02, 7.25698644e-03,
#          1.67483608e-01, 8.27551085e-04, 1.27315552e-04, 6.36577758e-05,
#          8.60653129e-02, 6.36577758e-05]]), array([0.10945403]))

# %% [markdown]
# ## Encoding Messages

# %%
### encode a message

# this is a random excerpt from Project Gutenberg's
# The Adventures of Sherlock Holmes, by Arthur Conan Doyle
# https://www.gutenberg.org/ebooks/1661

original_message = '''I then lounged down the street and found,
as I expected, that there was a mews in a lane which runs down
by one wall of the garden. I lent the ostlers a hand in rubbing
down their horses, and received in exchange twopence, a glass of
half-and-half, two fills of shag tobacco, and as much information
as I could desire about Miss Adler, to say nothing of half a dozen
other people in the neighbourhood in whom I was not in the least
interested, but whose biographies I was compelled to listen to.
'''

# Away they went, and I was just wondering whether I should not do well
# to follow them when up the lane came a neat little landau, the coachman
# with his coat only half-buttoned, and his tie under his ear, while all
# the tags of his harness were sticking out of the buckles. It hadn't
# pulled up before she shot out of the hall door and into it. I only
# caught a glimpse of her at the moment, but she was a lovely woman, with
# a face that a man might die for.

# My cabby drove fast. I don't think I ever drove faster, but the others
# were there before us. The cab and the landau with their steaming horses
# were in front of the door when I arrived. I paid the man and hurried
# into the church. There was not a soul there save the two whom I had
# followed and a surpliced clergyman, who seemed to be expostulating with
# them. They were all three standing in a knot in front of the altar. I
# lounged up the side aisle like any other idler who has dropped into a
# church. Suddenly, to my surprise, the three at the altar faced round to
# me, and Godfrey Norton came running as hard as he could towards me.

# %%
def encode_msg(msg):
    
    # lowercase everything and remove non-alpha charcaters
    msg = msg.lower()
    msg = regex.sub(" ", msg)
    
    coded_msg = []
    for ch in msg:
        coded_ch = ch
        if ch in true_mappings:
            coded_ch = true_mappings[ch]
        coded_msg.append(coded_ch)
            
    return "".join(coded_msg)

def decode_msg(msg, word_mapping):
    decoded_msg = []
    for ch in msg:
        decoded_ch = ch
        if ch in word_mapping:
            decoded_ch = word_mapping[ch]
        decoded_msg.append(decoded_ch)
            
    return "".join(decoded_msg)

# %%
encoded_msg = encode_msg(original_message)
print(encoded_msg)
# Out:
# x ucja igvayjm mgka ucj nuljju ram dgvam  rn x jpqjbujm  ucru ucjlj krn r hjkn xa r iraj kcxbc lvan mgka fo gaj krii gd ucj yrlmja  x ijau ucj gnuijln r cram xa lvffxay mgka ucjxl cglnjn  ram ljbjxwjm xa jpbcrayj ukgqjabj  r yirnn gd crid ram crid  ukg dxiin gd ncry ugfrbbg  ram rn hvbc xadglhruxga rn x bgvim mjnxlj rfgvu hxnn rmijl  ug nro agucxay gd crid r mgsja gucjl qjgqij xa ucj ajxycfgvlcggm xa kcgh x krn agu xa ucj ijrnu xaujljnujm  fvu kcgnj fxgylrqcxjn x krn bghqjiijm ug ixnuja ug

# %% [markdown]
# ## Genetic Evolutionary Algorithm to decode messages

# %%
def generate_dna_pool(n=20):
    dna_pool = []
    for _ in range(n):
        dna = list(string.ascii_lowercase)
        random.shuffle(dna)
        dna_pool.append(dna)
    
    return dna_pool

def procriate_offspring(dna_pool, n_children=3):
    
    offspring = []
    for parent in dna_pool:
        for _ in range(n_children):
            copy = parent.copy()
            i = np.random.randint(len(copy))
            j = np.random.randint(len(copy))
            
            # swap characters
            tmp = copy[i]
            copy[i] = copy[j]
            copy[j] = tmp
            
            offspring.append(copy)
            
    return offspring + dna_pool

# %%
def run_model(n_epochs=100):
    
    n_survivals = 5
    scores = np.zeros(n_epochs)
    best_dna = None
    best_map = None
    best_score = float('-inf')
    
    dna_pool = generate_dna_pool()
    
    for i in range(n_epochs):
        if i > 0:
            dna_pool = procriate_offspring(dna_pool, n_survivals)

        # calculate score for each dna
        dna2score = {}
        for dna in dna_pool:
            # build a map from current dna sequence
            current_map = {}
            for k,v in zip(letters1, dna):
                current_map[k] = v

            # decode using current map    
            decoded_msg = decode_msg(encoded_msg, current_map)
            score = get_sequence_prob(decoded_msg)

            # store this result
            dna2score[''.join(dna)] = score

            # check if this score is better than the best
            if score > best_score:
                best_score = score
                best_dna = dna
                best_map = current_map

        scores[i] = np.mean(list(dna2score.values()))

        # keep the best DNAs, survival of the fittest, using n_survivals
        sorted_dna = sorted(dna2score.items(), key=lambda x: x[1], reverse=True)
        dna_pool = [list(k) for k,v in sorted_dna[:n_survivals]]
#         [list(k) for k, v in sorted_dna[:5]]

        if i % 200 == 0:
            print("iter:", i, "score:", scores[i], "best so far:", best_score)
        
    return best_dna, best_map, best_score, scores

# %%
# Run the evolution!
n_epochs = 1000
best_dna, best_map, best_score, scores = run_model(n_epochs)
# Out:
# iter: 0 score: -2062.184439056681 best so far: -1774.5103379069421
# iter: 200 score: -1036.0586442040906 best so far: -929.5902922650557
# iter: 400 score: -1021.5983857358721 best so far: -929.5902922650557
# iter: 600 score: -1066.9281144808915 best so far: -929.5902922650557
# iter: 800 score: -1029.7864992265195 best so far: -929.5902922650557

# %%
# use best score
decoded_msg = decode_msg(encoded_msg, best_map)

print("LL of decoded with best mapping: ", get_sequence_prob(decoded_msg))
print("LL of original mapping: ", get_sequence_prob(regex.sub(" ", original_message.lower())))

for true, v in true_mappings.items():
    pred = best_map[v] # best map is a reverse map
    if true != pred:
        print(f"true: {true}, pred: {pred}")
# Out:
# LL of decoded with best mapping:  -929.5902922650557
# LL of original mapping:  -933.0312453751817
# true: k, pred: q
# true: q, pred: z
# true: z, pred: k

# %%
print("decoded message:\n\n", textwrap.fill(decoded_msg)) 

print("\noriginal message:\n\n", original_message)
# Out:
# decoded message:
#
#  i then lounged down the street and found  as i expected  that there
# was a mews in a lane which runs down by one wall of the garden  i lent
# the ostlers a hand in rubbing down their horses  and received in
# exchange twopence  a glass of half and half  two fills of shag tobacco
# and as much information as i could desire about miss adler  to say
# nothing of half a doken other people in the neighbourhood in whom i
# was not in the least interested  but whose biographies i was compelled
# to listen to
#
# original message:
#
#  I then lounged down the street and found,
# as I expected, that there was a mews in a lane which runs down
# by one wall of the garden. I lent the ostlers a hand in rubbing
# down their horses, and received in exchange twopence, a glass of
# half-and-half, two fills of shag tobacco, and as much information
# as I could desire about Miss Adler, to say nothing of half a dozen
# other people in the neighbourhood in whom I was not in the least
# interested, but whose biographies I was compelled to listen to.
