# %%
from typing import Union, List
import numpy as np
import matplotlib.pyplot as plt
import string
import random
import re
import requests
import os
import textwrap
import nltk
from nltk.stem import WordNetLemmatizer
from bs4 import BeautifulSoup

# %% [markdown]
# ## Building Trigram Model
#
# output should be like:
#
# {
#     ("I", "eggs"): {
#         "like": 0.67,
#         "love": 0.21,
#         ...
#     }
# }

# %%
# basic corpus to test
basic_corpus = """
    I like cats
    I like pizzas
    I want water
    He wants water
"""

# %%
# !ls ../sentiment-analysis/electronics/
# Out:
# negative.review  positive.review  unlabeled.review

# %%
positive_reviews = BeautifulSoup(open("../sentiment-analysis/electronics/positive.review").read(), features="html5lib").findAll("review_text")

# %%
positive_reviews[0]
# Out:
# <review_text>
# I purchased this unit due to frequent blackouts in my area and 2 power supplies going bad.  It will run my cable modem, router, PC, and LCD monitor for 5 minutes.  This is more than enough time to save work and shut down.   Equally important, I know that my electronics are receiving clean power.
#
# I feel that this investment is minor compared to the loss of valuable data or the failure of equipment due to a power spike or an irregular power supply.
#
# As always, Amazon had it to me in &lt;2 business days
# </review_text>

# %% [markdown]
# ## Language Model

# %%
# leveraging ord function to get integers from a character to use as index
ord("a"), ord("b"), ord("c")
# Out:
# (97, 98, 99)

# %% [markdown]
# markov matrix to store trigram probabilities
#
# we initialize with ones to consider "add-one smoothing"
#
# On the cipher exercise, we were using unigram and bigram calculations. For unigrams, it is easy: we just count words. For bigrams, we needed the unigram prob, so for $n-gram$ models we need all previous probabilities.
#
# In general, a trigram and $n-gram$ model have the following probabilities:
#
# $$p(w_t| w_{t-1}, w_{t-2}) = \frac{p(w_{t-2}\rightarrow w_{t-1} \rightarrow w_{t})}{p(w_{t-2}\rightarrow w_{t-1})} $$
#
# $$p(w_t| w_{t-1}, w_{t-2}, ...,w_{t-N+1}) = \frac{p(w_{t-N+1}\rightarrow ... \rightarrow w_{t-1} \rightarrow w_{t})}{p(w_{t-N+1}\rightarrow ... \rightarrow w_{t-1} )} $$
#
# Hence, the general formula is recursive.

# %%
# define which n-gram we want
ngram = 3 #trigram

M_2 = np.ones((26,26))

# initial state distribution (unigrams probabilities)
pi = np.zeros(26)

def update_trigrams(w1, w2, w3):
    pass

def update_bigrams(w1, w2):
    i = ord(w1) - 97
    j = ord(w2) - 97
    M[i,j] += 1
    
def update_unigrams(w):
    i = ord(w) - 97
    pi[i] += 1
    
# get log-probability of a word/token
def get_word_prob(word):
    
    probs = []
    # first word index
    i = ord(word[0]) - 97
    probs.append(np.log(pi[i]))
    
    # rest of sentence
    for w_previous, w in zip(word, word[1:]):
        i = ord(w_previous) - 97
        j = ord(w) - 97
        probs.append(np.log(M[i,j]))
        
    # find log-probability
    return sum(probs)

# get log-probability of a document, which is a sequence of words
def get_sequence_prob(doc:Union[str, List]):
    
    if type(doc) == str:
        doc = doc.split()
        
    prob = 0
    for word in doc:
        prob += get_word_prob(word)
        
    return prob

# %%
l = [1,2,4,5]
l[:-2]
# Out:
# [1, 2]

# %%
regex = re.compile('[^a-zA-Z]')

trigrams = {}
lemmatizer = WordNetLemmatizer()

with open("../sentiment-analysis/stopwords.txt") as f:
    stopwords = set(w.rstrip for w in f)

def my_tokenizer(sentence:str):
    s = sentence.lower()
    s = regex.sub(' ', s) 
    tokens = nltk.tokenize.word_tokenize(s)
    tokens = [t for t in tokens if len(t) > 2]
    tokens = [lemmatizer.lemmatize(t) for t in tokens]
    tokens = [t for t in tokens if t not in stopwords]

    return tokens

for review in positive_reviews:
    tokens = my_tokenizer(review.text)
    if tokens:
        # update our language model 
        for i, token in enumerate(tokens[:-2]):
            # update first unigram probs
            k = (tokens[i], tokens[i+2])
            if k not in trigrams:
                trigrams[k] = []
            # update the middle words seen on the example
            trigrams[k].append(tokens[i+1])
            

trigrams_probabilities = {}
for k, words in trigrams.items():
    if len(set(words)) > 1:
        d = {}
        n = 0
        for word in words:
            if word not in d:
                d[word] = 0
            d[word] += 1
            n += 1
        for w, c in d.items():
            d[w] = float(c) / n
            
        trigrams_probabilities[k] = d
            
# normalize probabilities
# pi /= pi.sum()
# M /= M.sum(axis=1, keepdims=True)

# %%
trigrams_probabilities
# Out:
# {('purchased', 'unit'): {'this': 0.5, 'the': 0.5},
#  ('modem', 'and'): {'router': 0.6666666666666666, 'phone': 0.3333333333333333},
#  ('and', 'monitor'): {'lcd': 0.5, 'the': 0.5},
#  ('for', 'this'): {'minute': 0.0625,
#   'le': 0.0625,
#   'hour': 0.0625,
#   'feedback': 0.0625,
#   'compatibility': 0.0625,
#   'security': 0.0625,
#   'sure': 0.125,
#   'spec': 0.0625,
#   'organization': 0.0625,
#   'more': 0.0625,
#   'the': 0.0625,
#   'traveling': 0.0625,
#   'use': 0.0625,
#   'amazon': 0.0625,
#   'vonage': 0.0625},
#  ('this', 'than'): {'more': 0.6666666666666666, 'device': 0.3333333333333333},
#  ('than', 'time'): {'enough': 0.3333333333333333,
#   'four': 0.3333333333333333,
#   'expected': 0.3333333333333333},
#  ('enough', 'save'): {'time': 0.5, 'space': 0.5},
#  ('time', 'work'): {'save': 0.5, 'for': 0.5},
#  ('save', 'and'): {'work': 0.5, 'some': 0.5},
#  ('and', 'down'): {'shut': 0.3333333333333333,
#   'transient': 0.3333333333333333,
#   'cool': 0.3333333333333333},
#  ('important', 'that'): {'know': 0.5, 'remember': 0.5},
#  ('that', 'are'): {'electronics': 0.07142857142857142,
#   'scratch': 0.07142857142857142,
#   'they': 0.21428571428571427,
#   'there': 0.21428571428571427,
#   'statement': 0.07142857142857142,
#   'you': 0.21428571428571427,
#   'battery': 0.07142857142857142,
#   'these': 0.07142857142857142},
#  ('power', 'that'): {'feel': 0.5, 'supply': 0.5},
#  ('minor', 'the'): {'compared': 0.25,
#   'excellent': 0.25,
#   'note': 0.25,
#   'criticism': 0.25},
#  ('had', 'day'): {'business': 0.3333333333333333,
#   'few': 0.3333333333333333,
#   'within': 0.3333333333333333},
#  ('back', 'the'): {'ups': 0.1111111111111111,
#   'exactly': 0.1111111111111111,
#   'soon': 0.1111111111111111,
#   'the': 0.1111111111111111,
#   'with': 0.1111111111111111,
#   'co': 0.1111111111111111,
#   'center': 0.1111111111111111,
#   'door': 0.1111111111111111,
#   'home': 0.1111111111111111},
#  ('work', 'had'): {'apc': 0.3333333333333333,
#   'have': 0.3333333333333333,
#   'perfect': 0.3333333333333333},
#  ('had', 'for'): {'them': 0.11764705882352941,
#   'now': 0.11764705882352941,
#   'coverage': 0.058823529411764705,
#   'going': 0.058823529411764705,
#   'mine': 0.11764705882352941,
#   'axim': 0.058823529411764705,
#   'expected': 0.058823529411764705,
#   'pocket': 0.058823529411764705,
#   'epson': 0.058823529411764705,
#   'vonage': 0.058823529411764705,
#   'the': 0.058823529411764705,
#   'charged': 0.058823529411764705,
#   'this': 0.11764705882352941},
#  ('them', 'about'): {'for': 0.6666666666666666, 'and': 0.3333333333333333},
#  ('for', 'month'): {'about': 0.45,
#   'over': 0.1,
#   'two': 0.1,
#   'almost': 0.1,
#   'last': 0.05,
#   'the': 0.05,
#   'couple': 0.05,
#   'few': 0.05,
#   'least': 0.05},
#  ('about', 'now'): {'month': 0.6666666666666666,
#   'that': 0.08333333333333333,
#   'year': 0.25},
#  ('any', 'they'): {'problem': 0.6666666666666666, 'help': 0.3333333333333333},
#  ('order', 'the'): {'more': 0.3333333333333333,
#   'from': 0.3333333333333333,
#   'belonging': 0.3333333333333333},
#  ('the', 'had'): {'unit': 0.07692307692307693,
#   'time': 0.038461538461538464,
#   'ipod': 0.038461538461538464,
#   'way': 0.038461538461538464,
#   'moment': 0.038461538461538464,
#   'output': 0.07692307692307693,
#   'disc': 0.038461538461538464,
#   'name': 0.038461538461538464,
#   'which': 0.038461538461538464,
#   'product': 0.038461538461538464,
#   'belkin': 0.038461538461538464,
#   'boonies': 0.038461538461538464,
#   'nano': 0.038461538461538464,
#   'screen': 0.038461538461538464,
#   'can': 0.038461538461538464,
#   'cable': 0.038461538461538464,
#   'market': 0.038461538461538464,
#   'headset': 0.038461538461538464,
#   'closest': 0.038461538461538464,
#   'sportapros': 0.038461538461538464,
#   'others': 0.038461538461538464,
#   'mdr': 0.038461538461538464,
#   'player': 0.038461538461538464,
#   'cord': 0.038461538461538464},
#  ('light', 'power'): {'when': 0.5, 'additional': 0.5},
#  ('when', 'the'): {'power': 0.02857142857142857,
#   'lanning': 0.02857142857142857,
#   'pulled': 0.02857142857142857,
#   'went': 0.02857142857142857,
#   'unplug': 0.02857142857142857,
#   'cranked': 0.02857142857142857,
#   'increased': 0.02857142857142857,
#   'facing': 0.02857142857142857,
#   'connect': 0.02857142857142857,
#   'compared': 0.02857142857142857,
#   'using': 0.08571428571428572,
#   'work': 0.02857142857142857,
#   'buy': 0.02857142857142857,
#   'come': 0.02857142857142857,
#   'clipped': 0.02857142857142857,
#   'bought': 0.02857142857142857,
#   'hearing': 0.02857142857142857,
#   'listening': 0.02857142857142857,
#   'attached': 0.02857142857142857,
#   'playing': 0.02857142857142857,
#   'putting': 0.05714285714285714,
#   'found': 0.02857142857142857,
#   'slung': 0.02857142857142857,
#   'switch': 0.02857142857142857,
#   'listen': 0.02857142857142857,
#   'turn': 0.02857142857142857,
#   'turned': 0.02857142857142857,
#   'wa': 0.02857142857142857,
#   'wanted': 0.02857142857142857,
#   'traveling': 0.02857142857142857,
#   'looped': 0.02857142857142857,
#   'kept': 0.02857142857142857},
#  ('the', 'missing'): {'unit': 0.5, 'feature': 0.5},
#  ('unit', 'the'): {'missing': 0.05555555555555555,
#   'for': 0.1111111111111111,
#   'clean': 0.05555555555555555,
#   'also': 0.05555555555555555,
#   'off': 0.05555555555555555,
#   'tune': 0.05555555555555555,
#   'pick': 0.1111111111111111,
#   'one': 0.1111111111111111,
#   'and': 0.1111111111111111,
#   'over': 0.05555555555555555,
#   'call': 0.05555555555555555,
#   'find': 0.05555555555555555,
#   'ha': 0.05555555555555555,
#   'locate': 0.05555555555555555},
#  ('only', 'the'): {'when': 0.03571428571428571,
#   'work': 0.03571428571428571,
#   'problem': 0.10714285714285714,
#   'get': 0.03571428571428571,
#   'adjusted': 0.03571428571428571,
#   'wa': 0.03571428571428571,
#   'use': 0.03571428571428571,
#   'hesitation': 0.03571428571428571,
#   'drawback': 0.07142857142857142,
#   'think': 0.03571428571428571,
#   'grabbed': 0.03571428571428571,
#   'good': 0.07142857142857142,
#   'covered': 0.07142857142857142,
#   'label': 0.03571428571428571,
#   'used': 0.07142857142857142,
#   'complaint': 0.03571428571428571,
#   'about': 0.03571428571428571,
#   'need': 0.03571428571428571,
#   'hear': 0.03571428571428571,
#   'downside': 0.07142857142857142,
#   'fit': 0.03571428571428571},
#  ('the', 'sound'): {'warning': 0.09523809523809523,
#   'digital': 0.047619047619047616,
#   'pico': 0.047619047619047616,
#   'clearly': 0.047619047619047616,
#   'quality': 0.09523809523809523,
#   'overall': 0.047619047619047616,
#   'difference': 0.047619047619047616,
#   'song': 0.047619047619047616,
#   'amazing': 0.047619047619047616,
#   'poor': 0.047619047619047616,
#   'full': 0.047619047619047616,
#   'best': 0.047619047619047616,
#   'speaker': 0.047619047619047616,
#   'beep': 0.047619047619047616,
#   'subtle': 0.047619047619047616,
#   'excellent': 0.047619047619047616,
#   'glass': 0.047619047619047616,
#   'picture': 0.047619047619047616,
#   'conversion': 0.047619047619047616},
#  ('like', 'sound'): {'lot': 0.5, 'testing': 0.5},
#  ('lot', 'you'): {'sound': 0.5, 'equipment': 0.5},
#  ('sound', 'hear'): {'you': 0.5, 'when': 0.5},
#  ('you', 'the'): {'hear': 0.013157894736842105,
#   'created': 0.013157894736842105,
#   'through': 0.013157894736842105,
#   'have': 0.09210526315789473,
#   'watch': 0.013157894736842105,
#   'get': 0.05263157894736842,
#   'change': 0.05263157894736842,
#   'found': 0.013157894736842105,
#   'connect': 0.02631578947368421,
#   'uninstall': 0.013157894736842105,
#   'using': 0.02631578947368421,
#   'merge': 0.013157894736842105,
#   'want': 0.039473684210526314,
#   'turn': 0.02631578947368421,
#   'set': 0.013157894736842105,
#   'see': 0.039473684210526314,
#   'given': 0.013157894736842105,
#   'save': 0.013157894736842105,
#   'hit': 0.013157894736842105,
#   'use': 0.06578947368421052,
#   'ask': 0.013157894736842105,
#   'need': 0.05263157894736842,
#   'risk': 0.013157894736842105,
#   'drain': 0.013157894736842105,
#   'heard': 0.013157894736842105,
#   'download': 0.013157894736842105,
#   'sync': 0.013157894736842105,
#   'leave': 0.013157894736842105,
#   'stop': 0.013157894736842105,
#   'left': 0.013157894736842105,
#   'break': 0.013157894736842105,
#   'wonder': 0.013157894736842105,
#   'drink': 0.013157894736842105,
#   'bought': 0.013157894736842105,
#   'slide': 0.013157894736842105,
#   'can': 0.02631578947368421,
#   'are': 0.02631578947368421,
#   'read': 0.013157894736842105,
#   'thinking': 0.013157894736842105,
#   'press': 0.013157894736842105,
#   'take': 0.013157894736842105,
#   'for': 0.013157894736842105,
#   'increase': 0.013157894736842105,
#   'learned': 0.013157894736842105,
#   'that': 0.013157894736842105,
#   'unlocked': 0.013157894736842105,
#   'list': 0.013157894736842105,
#   'editing': 0.013157894736842105},
#  ('the', 'isn'): {'house': 0.125,
#   'sound': 0.125,
#   'computer': 0.125,
#   'zip': 0.125,
#   'urc': 0.125,
#   'headset': 0.125,
#   'interface': 0.125,
#   'device': 0.125},
#  ('isn', 'easy'): {'always': 0.5, 'that': 0.5},
#  ('thick', 'and'): {'case': 0.3333333333333333,
#   'line': 0.3333333333333333,
#   'larger': 0.3333333333333333},
#  ('these', 'case'): {'slim': 0.6666666666666666, 'jewel': 0.3333333333333333},
#  ('most', 'will'): {'buyer': 0.3333333333333333,
#   'card': 0.3333333333333333,
#   'certainly': 0.3333333333333333},
#  ('will', 'them'): {'get': 0.14285714285714285,
#   'allow': 0.14285714285714285,
#   'satisfy': 0.14285714285714285,
#   'wear': 0.14285714285714285,
#   'love': 0.14285714285714285,
#   'order': 0.14285714285714285,
#   'cause': 0.14285714285714285},
#  ('get', 'for'): {'them': 0.3333333333333333,
#   'case': 0.1111111111111111,
#   'one': 0.2222222222222222,
#   'ready': 0.1111111111111111,
#   'memory': 0.1111111111111111,
#   'lot': 0.1111111111111111},
#  ('for', 'dvd'): {'use': 0.2,
#   'which': 0.2,
#   'panasonic': 0.2,
#   'your': 0.2,
#   'pure': 0.2},
#  ('dvd', 'and'): {'burning': 0.14285714285714285,
#   'player': 0.2857142857142857,
#   'movie': 0.14285714285714285,
#   'wife': 0.14285714285714285,
#   'audio': 0.14285714285714285,
#   'newbie': 0.14285714285714285},
#  ('and', 'are'): {'these': 0.1111111111111111,
#   'there': 0.05555555555555555,
#   'what': 0.027777777777777776,
#   'midranges': 0.027777777777777776,
#   'bicycle': 0.027777777777777776,
#   'they': 0.3055555555555556,
#   'series': 0.027777777777777776,
#   'memory': 0.027777777777777776,
#   'high': 0.027777777777777776,
#   'downloads': 0.027777777777777776,
#   'this': 0.027777777777777776,
#   'nanos': 0.027777777777777776,
#   'connector': 0.027777777777777776,
#   'you': 0.027777777777777776,
#   'instruction': 0.027777777777777776,
#   'thing': 0.027777777777777776,
#   'signal': 0.027777777777777776,
#   'height': 0.027777777777777776,
#   'remote': 0.027777777777777776,
#   'macro': 0.027777777777777776,
#   'color': 0.027777777777777776,
#   'nook': 0.027777777777777776},
#  ('from', 'company'): {'quality': 0.5, 'another': 0.5},
#  ('quality', 'for'): {'company': 0.2,
#   'but': 0.2,
#   'received': 0.2,
#   'great': 0.2,
#   'scanner': 0.2},
#  ('for', 'purpose'): {'that': 0.16666666666666666,
#   'many': 0.16666666666666666,
#   'other': 0.16666666666666666,
#   'the': 0.16666666666666666,
#   'almost': 0.16666666666666666,
#   'archival': 0.16666666666666666},
#  ('that', 'you'): {'purpose': 0.045454545454545456,
#   'let': 0.18181818181818182,
#   'way': 0.045454545454545456,
#   'matter': 0.045454545454545456,
#   'when': 0.3181818181818182,
#   'mean': 0.09090909090909091,
#   'what': 0.09090909090909091,
#   'give': 0.045454545454545456,
#   'routinely': 0.045454545454545456,
#   'mind': 0.045454545454545456,
#   'and': 0.045454545454545456},
#  ('you', 'want'): {'may': 0.23809523809523808,
#   'don': 0.19047619047619047,
#   'might': 0.19047619047619047,
#   'you': 0.047619047619047616,
#   'need': 0.09523809523809523,
#   'just': 0.14285714285714285,
#   'will': 0.047619047619047616,
#   'not': 0.047619047619047616},
#  ('consider', 'case'): {'larger': 0.5, 'having': 0.5},
#  ('your', 'but'): {'taste': 0.16666666666666666,
#   'body': 0.16666666666666666,
#   'eardrum': 0.16666666666666666,
#   'mind': 0.16666666666666666,
#   'ipod': 0.16666666666666666,
#   'hand': 0.16666666666666666},
#  ('but', 'these'): {'otherwise': 0.5, 'find': 0.5},
#  ('these', 'probably'): {'will': 0.6666666666666666,
#   'are': 0.3333333333333333},
#  ('will', 'satisfy'): {'probably': 0.5, 'easily': 0.5},
#  ('amazon', 'the'): {'one': 0.1,
#   'had': 0.3,
#   'during': 0.1,
#   'win': 0.1,
#   'page': 0.1,
#   'having': 0.1,
#   'for': 0.1,
#   'almost': 0.1},
#  ('they', 'the'): {'deliver': 0.07692307692307693,
#   'hold': 0.07692307692307693,
#   'one': 0.07692307692307693,
#   'give': 0.07692307692307693,
#   'are': 0.23076923076923078,
#   'sound': 0.07692307692307693,
#   'amazed': 0.07692307692307693,
#   'serve': 0.07692307692307693,
#   'pain': 0.07692307692307693,
#   'get': 0.07692307692307693,
#   'reveal': 0.07692307692307693},
#  ('product', 'and'): {'intime': 0.25, 'high': 0.25, 'work': 0.25, 'ad': 0.25},
#  ('and', 'item'): {'the': 0.5, 'quality': 0.5},
#  ('are', 'very'): {'working': 0.14285714285714285,
#   'not': 0.14285714285714285,
#   'few': 0.2857142857142857,
#   'also': 0.14285714285714285,
#   'both': 0.14285714285714285,
#   'then': 0.14285714285714285},
#  ('card', 'very'): {'working': 0.3333333333333333,
#   'size': 0.3333333333333333,
#   'overall': 0.3333333333333333},
#  ('very', 'with'): {'good': 0.017241379310344827,
#   'happy': 0.3793103448275862,
#   'pleased': 0.29310344827586204,
#   'low': 0.017241379310344827,
#   'satisfied': 0.1206896551724138,
#   'impressed': 0.08620689655172414,
#   'common': 0.017241379310344827,
#   'helpful': 0.017241379310344827,
#   'sturdy': 0.017241379310344827,
#   'confident': 0.017241379310344827,
#   'familiar': 0.017241379310344827},
#  ('out', 'any'): {'giving': 0.5, 'nor': 0.5},
#  ('any', 'one'): {'problem': 0.5, 'bad': 0.5},
#  ('problem', 'can'): {'one': 0.3333333333333333,
#   'you': 0.3333333333333333,
#   'entirely': 0.3333333333333333},
#  ('always', 'for'): {'amazon': 0.5, 'that': 0.5},
#  ('this', 'wa'): {'product': 0.2,
#   'set': 0.03333333333333333,
#   'one': 0.16666666666666666,
#   'system': 0.03333333333333333,
#   'monitor': 0.03333333333333333,
#   'purchase': 0.06666666666666667,
#   'installation': 0.03333333333333333,
#   'case': 0.03333333333333333,
#   'review': 0.03333333333333333,
#   'device': 0.03333333333333333,
#   'splitter': 0.03333333333333333,
#   'unit': 0.03333333333333333,
#   'swivel': 0.03333333333333333,
#   'dock': 0.03333333333333333,
#   'modem': 0.03333333333333333,
#   'printer': 0.06666666666666667,
#   'phone': 0.06666666666666667,
#   'testing': 0.03333333333333333},
#  ('perfect', 'case'): {'sturdy': 0.5, 'ipod': 0.5},
#  ('that', 'large'): {'hold': 0.5, 'ha': 0.5},
#  ('large', 'and'): {'collection': 0.2,
#   'enough': 0.2,
#   'screen': 0.4,
#   'display': 0.2},
#  ('and', 'other'): {'dvd': 0.07692307692307693,
#   'some': 0.07692307692307693,
#   'the': 0.5384615384615384,
#   'many': 0.07692307692307693,
#   'far': 0.07692307692307693,
#   'compare': 0.07692307692307693,
#   'various': 0.07692307692307693},
#  ('were', 'and'): {'flimsy': 0.14285714285714285,
#   'longer': 0.14285714285714285,
#   'recorded': 0.14285714285714285,
#   'brighter': 0.14285714285714285,
#   'dynamic': 0.14285714285714285,
#   'dropped': 0.14285714285714285,
#   'next': 0.14285714285714285},
#  ('and', 'out'): {'wore': 0.1111111111111111,
#   'found': 0.1111111111111111,
#   'come': 0.1111111111111111,
#   'figured': 0.1111111111111111,
#   'rock': 0.1111111111111111,
#   'sitting': 0.1111111111111111,
#   'tried': 0.1111111111111111,
#   'find': 0.1111111111111111,
#   'turned': 0.1111111111111111},
#  ('out', 'this'): {'fast': 0.2, 'that': 0.4, 'thumb': 0.2, 'there': 0.2},
#  ('fast', 'one'): {'this': 0.5, 'forward': 0.5},
#  ('this', 'ha'): {'one': 0.06451612903225806,
#   'recorder': 0.03225806451612903,
#   'phone': 0.0967741935483871,
#   'baby': 0.03225806451612903,
#   'would': 0.03225806451612903,
#   'model': 0.12903225806451613,
#   'keyboard': 0.03225806451612903,
#   'monitor': 0.06451612903225806,
#   'sony': 0.03225806451612903,
#   'mount': 0.03225806451612903,
#   'card': 0.0967741935483871,
#   'unit': 0.06451612903225806,
#   'backpack': 0.03225806451612903,
#   'case': 0.03225806451612903,
#   'samsung': 0.03225806451612903,
#   'system': 0.03225806451612903,
#   'player': 0.03225806451612903,
#   'gamepad': 0.06451612903225806,
#   'printer': 0.03225806451612903,
#   'product': 0.03225806451612903},
#  ('outside', 'and'): {'shell': 0.5, 'window': 0.5},
#  ('the', 'hold'): {'inside': 0.3333333333333333,
#   'covered': 0.3333333333333333,
#   'case': 0.3333333333333333},
#  ('dvd', 'have'): {'nicely': 0.25, 'ram': 0.25, 'and': 0.25, 'that': 0.25},
#  ('have', 'and'): {'complaint': 0.0625,
#   'bought': 0.0625,
#   'mac': 0.0625,
#   'searched': 0.125,
#   'when': 0.0625,
#   'copy': 0.0625,
#   'freedom': 0.0625,
#   'something': 0.0625,
#   'directv': 0.0625,
#   'pick': 0.0625,
#   'gateway': 0.0625,
#   'engraved': 0.0625,
#   'had': 0.0625,
#   'tmj': 0.0625,
#   'laptop': 0.0625},
#  ('complaint', 'the'): {'and': 0.1111111111111111,
#   'about': 0.3333333333333333,
#   'though': 0.1111111111111111,
#   'that': 0.3333333333333333,
#   'have': 0.1111111111111111},
#  ('and', 'price'): {'the': 0.5,
#   'good': 0.14285714285714285,
#   'fair': 0.07142857142857142,
#   'total': 0.07142857142857142,
#   'great': 0.07142857142857142,
#   'excellent': 0.07142857142857142,
#   'lower': 0.07142857142857142},
#  ('the', 'paid'): {'price': 0.5, 'wire': 0.25, 'buck': 0.25},
#  ('price', 'say'): {'paid': 0.5, 'for': 0.5},
#  ('this', 'great'): {'wa': 0.15,
#   'product': 0.1,
#   'one': 0.05,
#   'radio': 0.1,
#   'really': 0.05,
#   'phone': 0.05,
#   'make': 0.05,
#   'thing': 0.1,
#   'transmitter': 0.05,
#   'nano': 0.05,
#   'screen': 0.05,
#   'card': 0.05,
#   'device': 0.05,
#   'keyboard': 0.05,
#   'reciever': 0.05},
#  ('great', 'for'): {'value': 0.25925925925925924,
#   'battery': 0.037037037037037035,
#   'product': 0.07407407407407407,
#   'back': 0.037037037037037035,
#   'way': 0.037037037037037035,
#   'cam': 0.037037037037037035,
#   'saving': 0.037037037037037035,
#   'price': 0.037037037037037035,
#   'quality': 0.037037037037037035,
#   'headset': 0.037037037037037035,
#   'feature': 0.037037037037037035,
#   'unit': 0.037037037037037035,
#   'phone': 0.037037037037037035,
#   'keyboard': 0.037037037037037035,
#   'buy': 0.07407407407407407,
#   'case': 0.037037037037037035,
#   'also': 0.037037037037037035,
#   'angle': 0.037037037037037035,
#   'gadget': 0.037037037037037035},
#  ('value', 'your'): {'for': 0.6666666666666666, 'then': 0.3333333333333333},
#  ('for', 'money'): {'your': 0.18181818181818182,
#   'the': 0.7727272727272727,
#   'their': 0.045454545454545456},
#  ('ha', 'been'): {'always': 0.5, 'not': 0.5},
#  ('company', 'the'): {'and': 0.6666666666666666, 'well': 0.3333333333333333},
#  ('the', 'go'): {'same': 0.4, 'clip': 0.2, 'saying': 0.2, 'product': 0.2},
#  ('for', 'product'): {'this': 0.5555555555555556,
#   'the': 0.3333333333333333,
#   'great': 0.1111111111111111},
#  ('very', 'use'): {'much': 0.15384615384615385,
#   'easy': 0.6923076923076923,
#   'clear': 0.07692307692307693,
#   'simple': 0.07692307692307693},
#  ('for', 'game'): {'wild': 0.6666666666666666, 'the': 0.3333333333333333},
#  ('hold', 'picture'): {'several': 0.6666666666666666,
#   'about': 0.3333333333333333},
#  ('several', 'and'): {'picture': 0.5, 'time': 0.25, 'month': 0.25},
#  ('and', 'been'): {'ha': 0.35714285714285715,
#   'have': 0.5,
#   'having': 0.07142857142857142,
#   'generally': 0.07142857142857142},
#  ('ha', 'the'): {'been': 0.15,
#   'limit': 0.05,
#   'certified': 0.05,
#   'all': 0.2,
#   'twice': 0.05,
#   'bothered': 0.05,
#   'switch': 0.05,
#   'that': 0.05,
#   'cut': 0.05,
#   'broken': 0.05,
#   'dent': 0.05,
#   'wire': 0.05,
#   'one': 0.05,
#   'provided': 0.05,
#   'close': 0.05},
#  ('the', 'all'): {'camera': 0.125,
#   'installation': 0.0625,
#   'bass': 0.0625,
#   'viewer': 0.0625,
#   'brightness': 0.0625,
#   'router': 0.0625,
#   'charger': 0.0625,
#   'movie': 0.0625,
#   'longest': 0.0625,
#   'surpassed': 0.0625,
#   'menu': 0.0625,
#   'speaker': 0.0625,
#   'headband': 0.125,
#   'microsoft': 0.0625},
#  ('kind', 'would'): {'weather': 0.6666666666666666,
#   'mouse': 0.3333333333333333},
#  ('buy', 'again'): {'kingston': 0.3333333333333333,
#   'them': 0.16666666666666666,
#   'one': 0.3333333333333333,
#   'these': 0.16666666666666666},
#  ('had', 'with'): {'problem': 0.75,
#   'success': 0.05,
#   'issue': 0.05,
#   'more': 0.05,
#   'trouble': 0.05,
#   'phone': 0.05},
#  ('problem', 'this'): {'with': 0.6666666666666666,
#   'find': 0.16666666666666666,
#   'making': 0.16666666666666666},
#  ('with', 'card'): {'this': 0.4,
#   'netgear': 0.2,
#   'credit': 0.2,
#   'adapter': 0.2},
#  ('this', 'and'): {'card': 0.04081632653061224,
#   'item': 0.04081632653061224,
#   'short': 0.02040816326530612,
#   'notebook': 0.02040816326530612,
#   'deluxe': 0.02040816326530612,
#   'purchase': 0.02040816326530612,
#   'kodak': 0.02040816326530612,
#   'brand': 0.02040816326530612,
#   'one': 0.061224489795918366,
#   'drive': 0.04081632653061224,
#   'good': 0.02040816326530612,
#   'viewsonic': 0.02040816326530612,
#   'monitor': 0.02040816326530612,
#   'base': 0.04081632653061224,
#   'investment': 0.02040816326530612,
#   'minimal': 0.02040816326530612,
#   'thing': 0.02040816326530612,
#   'page': 0.02040816326530612,
#   'fixed': 0.02040816326530612,
#   'mouse': 0.04081632653061224,
#   'printer': 0.04081632653061224,
#   'enough': 0.02040816326530612,
#   'expected': 0.02040816326530612,
#   'software': 0.02040816326530612,
#   'stand': 0.02040816326530612,
#   'first': 0.02040816326530612,
#   'model': 0.02040816326530612,
#   'headset': 0.04081632653061224,
#   'protector': 0.02040816326530612,
#   'configuration': 0.02040816326530612,
#   'charger': 0.02040816326530612,
#   'product': 0.02040816326530612,
#   'phone': 0.061224489795918366,
#   'modem': 0.02040816326530612,
#   'problem': 0.02040816326530612,
#   'capacity': 0.02040816326530612,
#   'hardware': 0.02040816326530612,
#   'switch': 0.02040816326530612},
#  ('card', 'the'): {'and': 0.2222222222222222,
#   'handle': 0.1111111111111111,
#   'drain': 0.1111111111111111,
#   'onto': 0.1111111111111111,
#   'support': 0.1111111111111111,
#   'all': 0.1111111111111111,
#   'like': 0.1111111111111111,
#   'plug': 0.1111111111111111},
#  ('and', 'delivery'): {'the': 0.5, 'service': 0.5},
#  ('the', 'wa'): {'delivery': 0.0136986301369863,
#   'remote': 0.0273972602739726,
#   'than': 0.0136986301369863,
#   'way': 0.0136986301369863,
#   'subject': 0.0136986301369863,
#   'service': 0.0273972602739726,
#   'box': 0.0136986301369863,
#   'thing': 0.0136986301369863,
#   'quality': 0.0273972602739726,
#   'sound': 0.0547945205479452,
#   'answer': 0.0136986301369863,
#   'purchased': 0.0136986301369863,
#   'unit': 0.0136986301369863,
#   'sharp': 0.0136986301369863,
#   'price': 0.1232876712328767,
#   'communication': 0.0136986301369863,
#   'le': 0.0136986301369863,
#   'picture': 0.0136986301369863,
#   'subwoofer': 0.0136986301369863,
#   'diamondback': 0.0136986301369863,
#   'gamepad': 0.0136986301369863,
#   'market': 0.0136986301369863,
#   'packaging': 0.0136986301369863,
#   'interface': 0.0136986301369863,
#   'idea': 0.0136986301369863,
#   'past': 0.0136986301369863,
#   'product': 0.0410958904109589,
#   'mix': 0.0136986301369863,
#   'shipping': 0.0136986301369863,
#   'intall': 0.0136986301369863,
#   'equipment': 0.0136986301369863,
#   'sub': 0.0136986301369863,
#   'headset': 0.0273972602739726,
#   'device': 0.0136986301369863,
#   'destination': 0.0136986301369863,
#   'purchase': 0.0136986301369863,
#   'dock': 0.0136986301369863,
#   'that': 0.0136986301369863,
#   'software': 0.0273972602739726,
#   'machine': 0.0136986301369863,
#   'game': 0.0136986301369863,
#   'pad': 0.0136986301369863,
#   'volume': 0.0136986301369863,
#   'srf': 0.0136986301369863,
#   'cable': 0.0136986301369863,
#   'house': 0.0136986301369863,
#   'ique': 0.0136986301369863,
#   'strap': 0.0136986301369863,
#   'mount': 0.0136986301369863,
#   'phone': 0.0136986301369863,
#   'wall': 0.0136986301369863,
#   'theater': 0.0136986301369863,
#   'antenna': 0.0136986301369863,
#   'problem': 0.0136986301369863,
#   'ring': 0.0136986301369863},
#  ('prompt', 'you'): {'thank': 0.5, 'give': 0.5},
#  ('after', 'through'): {'going': 0.6666666666666666,
#   'searching': 0.3333333333333333},
#  ('going', 'the'): {'through': 0.2,
#   'use': 0.2,
#   'back': 0.1,
#   'into': 0.1,
#   'with': 0.1,
#   'strong': 0.2,
#   'buy': 0.1},
#  ('through', 'review'): {'the': 0.5, 'lot': 0.5},
#  ('the', 'bought'): {'review': 0.2222222222222222,
#   'reason': 0.2222222222222222,
#   'one': 0.1111111111111111,
#   'spec': 0.1111111111111111,
#   'quest': 0.1111111111111111,
#   'best': 0.1111111111111111,
#   'package': 0.1111111111111111},
#  ('review', 'this'): {'bought': 0.2,
#   'for': 0.1,
#   'here': 0.1,
#   'because': 0.1,
#   'state': 0.1,
#   'bash': 0.1,
#   'about': 0.1,
#   'found': 0.1,
#   'recommending': 0.1},
#  ('bought', 'card'): {'this': 0.5, 'two': 0.5},
#  ('this', 'for'): {'card': 0.07692307692307693,
#   'product': 0.09615384615384616,
#   'drive': 0.019230769230769232,
#   'monitor': 0.019230769230769232,
#   'question': 0.019230769230769232,
#   'wonderful': 0.038461538461538464,
#   'one': 0.07692307692307693,
#   'unit': 0.038461538461538464,
#   'iterm': 0.019230769230769232,
#   'router': 0.019230769230769232,
#   'item': 0.038461538461538464,
#   'out': 0.019230769230769232,
#   'regard': 0.019230769230769232,
#   'and': 0.019230769230769232,
#   'mouse': 0.019230769230769232,
#   'camera': 0.019230769230769232,
#   'online': 0.019230769230769232,
#   'phone': 0.019230769230769232,
#   'request': 0.019230769230769232,
#   'wa': 0.019230769230769232,
#   'quality': 0.019230769230769232,
#   'perfect': 0.11538461538461539,
#   'printer': 0.038461538461538464,
#   'backpack': 0.019230769230769232,
#   'cable': 0.038461538461538464,
#   'keyboard': 0.019230769230769232,
#   'receiver': 0.019230769230769232,
#   'headset': 0.019230769230769232,
#   'model': 0.019230769230769232,
#   'controller': 0.019230769230769232,
#   'headphone': 0.019230769230769232,
#   'player': 0.019230769230769232},
#  ('for', 'digital'): {'canon': 0.25,
#   'friend': 0.25,
#   'every': 0.25,
#   'your': 0.25},
#  ('digital', 'when'): {'photographer': 0.5, 'receiver': 0.5},
#  ('the', 'empty'): {'card': 0.5, 'medium': 0.5},
#  ('though', 'bit'): {'take': 0.5, 'may': 0.5},
#  ('bit', 'than'): {'longer': 0.16666666666666666,
#   'wider': 0.16666666666666666,
#   'smaller': 0.16666666666666666,
#   'more': 0.3333333333333333,
#   'larger': 0.16666666666666666},
#  ('wa', 'with'): {'used': 0.0625,
#   'using': 0.0625,
#   'worse': 0.0625,
#   'solved': 0.0625,
#   'built': 0.0625,
#   'mislead': 0.0625,
#   'impressed': 0.0625,
#   'installed': 0.0625,
#   'pleased': 0.0625,
#   'pictured': 0.125,
#   'familiar': 0.0625,
#   'but': 0.0625,
#   'plagued': 0.0625,
#   'happy': 0.0625,
#   'done': 0.0625},
#  ('with', 'and'): {'point': 0.020833333333333332,
#   'machine': 0.020833333333333332,
#   'this': 0.020833333333333332,
#   'iriver': 0.020833333333333332,
#   'window': 0.020833333333333332,
#   'mac': 0.041666666666666664,
#   'multiple': 0.020833333333333332,
#   'itunes': 0.020833333333333332,
#   'set': 0.020833333333333332,
#   'player': 0.041666666666666664,
#   'compact': 0.020833333333333332,
#   'case': 0.020833333333333332,
#   'keyboard': 0.020833333333333332,
#   'them': 0.0625,
#   'these': 0.020833333333333332,
#   'itrip': 0.020833333333333332,
#   'line': 0.020833333333333332,
#   'caller': 0.020833333333333332,
#   'netgear': 0.020833333333333332,
#   'laptop': 0.0625,
#   'motorola': 0.020833333333333332,
#   'type': 0.020833333333333332,
#   'printer': 0.020833333333333332,
#   'mouse': 0.020833333333333332,
#   'problem': 0.020833333333333332,
#   'the': 0.020833333333333332,
#   'dragon': 0.020833333333333332,
#   'phone': 0.020833333333333332,
#   'already': 0.020833333333333332,
#   'install': 0.020833333333333332,
#   'starbucks': 0.020833333333333332,
#   'direction': 0.020833333333333332,
#   'purchase': 0.020833333333333332,
#   'friend': 0.041666666666666664,
#   'usb': 0.020833333333333332,
#   'wireless': 0.020833333333333332,
#   'range': 0.020833333333333332,
#   'husband': 0.020833333333333332,
#   'mount': 0.020833333333333332,
#   'canon': 0.020833333333333332,
#   'street': 0.020833333333333332},
#  ('happy', 'this'): {'with': 0.8181818181818182,
#   'purchased': 0.09090909090909091,
#   'made': 0.09090909090909091},
#  ('with', 'product'): {'this': 0.36363636363636365,
#   'the': 0.2727272727272727,
#   'both': 0.045454545454545456,
#   'you': 0.045454545454545456,
#   'apple': 0.045454545454545456,
#   'sandisk': 0.045454545454545456,
#   'their': 0.09090909090909091,
#   'apc': 0.045454545454545456,
#   'wenger': 0.045454545454545456},
#  ('good', 'not'): {'sound': 0.2,
#   'disclaimer': 0.2,
#   'but': 0.2,
#   'stereo': 0.2,
#   'you': 0.2},
#  ('not', 'quality'): {'bose': 0.3333333333333333,
#   'the': 0.3333333333333333,
#   'great': 0.3333333333333333},
#  ('but', 'the'): {'for': 0.1388888888888889,
#   'then': 0.05555555555555555,
#   'sense': 0.027777777777777776,
#   'everything': 0.027777777777777776,
#   'enjoyable': 0.027777777777777776,
#   'with': 0.1111111111111111,
#   'not': 0.05555555555555555,
#   'only': 0.027777777777777776,
#   'wa': 0.027777777777777776,
#   'since': 0.027777777777777776,
#   'hoped': 0.027777777777777776,
#   'had': 0.027777777777777776,
#   'usually': 0.027777777777777776,
#   'soon': 0.027777777777777776,
#   'here': 0.027777777777777776,
#   'big': 0.027777777777777776,
#   'have': 0.027777777777777776,
#   'found': 0.027777777777777776,
#   'from': 0.027777777777777776,
#   'fact': 0.027777777777777776,
#   'get': 0.027777777777777776,
#   'like': 0.027777777777777776,
#   'due': 0.027777777777777776,
#   'out': 0.027777777777777776,
#   'doe': 0.027777777777777776,
#   'because': 0.027777777777777776,
#   'received': 0.027777777777777776},
#  ('for', 'price'): {'the': 0.7884615384615384,
#   'good': 0.019230769230769232,
#   'this': 0.019230769230769232,
#   'full': 0.019230769230769232,
#   'that': 0.019230769230769232,
#   'decent': 0.019230769230769232,
#   'fantastic': 0.019230769230769232,
#   'it': 0.038461538461538464,
#   'excellent': 0.019230769230769232,
#   'everyday': 0.019230769230769232,
#   'low': 0.019230769230769232},
#  ('the', 'very'): {'price': 0.03225806451612903,
#   'show': 0.03225806451612903,
#   'same': 0.03225806451612903,
#   'sound': 0.0967741935483871,
#   'bass': 0.06451612903225806,
#   'middle': 0.03225806451612903,
#   'response': 0.03225806451612903,
#   'result': 0.03225806451612903,
#   'mouse': 0.06451612903225806,
#   'labeling': 0.03225806451612903,
#   'design': 0.06451612903225806,
#   'radio': 0.03225806451612903,
#   'vol': 0.03225806451612903,
#   'bose': 0.03225806451612903,
#   'floor': 0.03225806451612903,
#   'player': 0.03225806451612903,
#   'subwoofer': 0.03225806451612903,
#   'bottom': 0.03225806451612903,
#   'range': 0.03225806451612903,
#   'usb': 0.03225806451612903,
#   'beginning': 0.03225806451612903,
#   'picture': 0.03225806451612903,
#   'felt': 0.03225806451612903,
#   'difference': 0.03225806451612903,
#   'wire': 0.03225806451612903,
#   'hand': 0.03225806451612903},
#  ('very', 'had'): {'respectable': 0.5, 'nice': 0.5},
#  ('had', 'year'): {'almost': 0.3333333333333333,
#   'improved': 0.3333333333333333,
#   'had': 0.3333333333333333},
#  ('almost', 'and'): {'year': 0.8, 'week': 0.2},
#  ('many', 'get'): {'weekend': 0.5, 'hour': 0.5},
#  ('get', 'and'): {'aways': 0.25, 'price': 0.25, 'signal': 0.25, 'lost': 0.25},
#  ('and', 'great'): {'work': 0.2,
#   'ha': 0.1,
#   'always': 0.05,
#   'look': 0.1,
#   'print': 0.05,
#   'do': 0.05,
#   'are': 0.05,
#   'audio': 0.05,
#   'worked': 0.15,
#   'make': 0.05,
#   'have': 0.05,
#   'sound': 0.05,
#   'wa': 0.05},
#  ('use', 'wa'): {'alot': 0.3333333333333333,
#   'downloading': 0.3333333333333333,
#   'well': 0.3333333333333333},
#  ('wa', 'purchase'): {'good': 0.6, 'silly': 0.2, 'great': 0.2},
#  ('good', 'for'): {'purchase': 0.04,
#   'idea': 0.04,
#   'price': 0.04,
#   'logitech': 0.04,
#   'sound': 0.08,
#   'enough': 0.08,
#   'reason': 0.04,
#   'news': 0.04,
#   'choice': 0.04,
#   'value': 0.12,
#   'case': 0.04,
#   'deal': 0.04,
#   'cadadate': 0.04,
#   'skin': 0.04,
#   'balance': 0.04,
#   'great': 0.04,
#   'headset': 0.04,
#   'time': 0.04,
#   'especially': 0.04,
#   'design': 0.04,
#   'while': 0.04},
#  ('this', 'because'): {'reader': 0.07142857142857142,
#   'format': 0.07142857142857142,
#   'unit': 0.07142857142857142,
#   'mouse': 0.07142857142857142,
#   'base': 0.07142857142857142,
#   'hotas': 0.07142857142857142,
#   'item': 0.07142857142857142,
#   'one': 0.14285714285714285,
#   'online': 0.07142857142857142,
#   'product': 0.07142857142857142,
#   'purchase': 0.07142857142857142,
#   'star': 0.07142857142857142,
#   'may': 0.07142857142857142},
#  ('camera', 'all'): {'and': 0.5, 'however': 0.5},
#  ('and', 'it'): {'all': 0.3333333333333333,
#   'did': 0.3333333333333333,
#   'learning': 0.3333333333333333},
#  ('all', 'cable'): {'it': 0.3333333333333333,
#   'not': 0.3333333333333333,
#   'these': 0.3333333333333333},
#  ('attached', 'the'): {'download': 0.5, 'even': 0.5},
#  ('the', 'and'): {'picture': 0.017921146953405017,
#   'charger': 0.0035842293906810036,
#   'host': 0.0035842293906810036,
#   'time': 0.010752688172043012,
#   'camera': 0.007168458781362007,
#   'attachment': 0.0035842293906810036,
#   'king': 0.0035842293906810036,
#   'past': 0.017921146953405017,
#   'wap': 0.0035842293906810036,
#   'box': 0.014336917562724014,
#   'ipod': 0.017921146953405017,
#   'screen': 0.014336917562724014,
#   'laptop': 0.0035842293906810036,
#   'card': 0.0035842293906810036,
#   'signal': 0.007168458781362007,
#   'built': 0.0035842293906810036,
#   'car': 0.007168458781362007,
#   'transmitter': 0.0035842293906810036,
#   'video': 0.010752688172043012,
#   'earphone': 0.0035842293906810036,
#   'quality': 0.017921146953405017,
#   'monitor': 0.0035842293906810036,
#   'dvd': 0.0035842293906810036,
#   'disc': 0.007168458781362007,
#   'buffer': 0.0035842293906810036,
#   'drm': 0.0035842293906810036,
#   'cost': 0.007168458781362007,
#   'problem': 0.010752688172043012,
#   'high': 0.0035842293906810036,
#   'installation': 0.0035842293906810036,
#   'phone': 0.0035842293906810036,
#   'cable': 0.0035842293906810036,
#   'volume': 0.007168458781362007,
#   'price': 0.021505376344086023,
#   'room': 0.010752688172043012,
#   'menu': 0.0035842293906810036,
#   'water': 0.0035842293906810036,
#   'buy': 0.0035842293906810036,
#   'image': 0.0035842293906810036,
#   'sound': 0.03225806451612903,
#   'printer': 0.0035842293906810036,
#   'tivoli': 0.0035842293906810036,
#   'player': 0.014336917562724014,
#   'cpu': 0.0035842293906810036,
#   'fang': 0.0035842293906810036,
#   'epson': 0.0035842293906810036,
#   'market': 0.010752688172043012,
#   'line': 0.0035842293906810036,
#   'thing': 0.0035842293906810036,
#   'house': 0.007168458781362007,
#   'light': 0.0035842293906810036,
#   'comfort': 0.0035842293906810036,
#   'mouse': 0.010752688172043012,
#   'ink': 0.0035842293906810036,
#   'remote': 0.0035842293906810036,
#   'value': 0.0035842293906810036,
#   'speaker': 0.0035842293906810036,
#   'manufacturing': 0.0035842293906810036,
#   'drive': 0.007168458781362007,
#   'unit': 0.007168458781362007,
#   'pair': 0.0035842293906810036,
#   'yesterday': 0.0035842293906810036,
#   'bass': 0.007168458781362007,
#   'bpo': 0.0035842293906810036,
#   'dust': 0.0035842293906810036,
#   'samsungs': 0.0035842293906810036,
#   'clarity': 0.0035842293906810036,
#   'device': 0.007168458781362007,
#   'side': 0.0035842293906810036,
#   'driver': 0.0035842293906810036,
#   'router': 0.0035842293906810036,
#   'network': 0.0035842293906810036,
#   'newer': 0.007168458781362007,
#   'keyboard': 0.010752688172043012,
#   'battery': 0.0035842293906810036,
#   'middle': 0.010752688172043012,
#   'mids': 0.007168458781362007,
#   'wire': 0.007168458781362007,
#   'clock': 0.0035842293906810036,
#   'bell': 0.007168458781362007,
#   'email': 0.0035842293906810036,
#   'sleakest': 0.0035842293906810036,
#   'closet': 0.0035842293906810036,
#   'floorboard': 0.0035842293906810036,
#   'tupperware': 0.0035842293906810036,
#   'pot': 0.0035842293906810036,
#   'mac': 0.0035842293906810036,
#   'pc': 0.0035842293906810036,
#   'action': 0.0035842293906810036,
#   'sensetivity': 0.0035842293906810036,
#   'element': 0.0035842293906810036,
#   'aspiring': 0.0035842293906810036,
#   'year': 0.007168458781362007,
#   'city': 0.0035842293906810036,
#   'install': 0.0035842293906810036,
#   'receiver': 0.0035842293906810036,
#   'weight': 0.0035842293906810036,
#   'nano': 0.0035842293906810036,
#   'wringer': 0.0035842293906810036,
#   'bullet': 0.0035842293906810036,
#   'run': 0.0035842293906810036,
#   'prince': 0.0035842293906810036,
#   'guitar': 0.0035842293906810036,
#   'red': 0.0035842293906810036,
#   'travel': 0.007168458781362007,
#   'range': 0.0035842293906810036,
#   'way': 0.007168458781362007,
#   'zune': 0.0035842293906810036,
#   'rattle': 0.0035842293906810036,
#   'button': 0.0035842293906810036,
#   'transfer': 0.0035842293906810036,
#   'rain': 0.0035842293906810036,
#   'purchase': 0.0035842293906810036,
#   'cam': 0.0035842293906810036,
#   'mic': 0.0035842293906810036,
#   'bose': 0.0035842293906810036,
#   'dock': 0.0035842293906810036,
#   'back': 0.007168458781362007,
#   'cartridge': 0.0035842293906810036,
#   'post': 0.0035842293906810036,
#   'geforce': 0.0035842293906810036,
#   'accuracy': 0.0035842293906810036,
#   'color': 0.010752688172043012,
#   'beach': 0.0035842293906810036,
#   'hotel': 0.0035842293906810036,
#   'analog': 0.0035842293906810036,
#   'windex': 0.0035842293906810036,
#   'chord': 0.0035842293906810036,
#   'wall': 0.007168458781362007,
#   'blockiness': 0.0035842293906810036,
#   'monster': 0.0035842293906810036,
#   'white': 0.0035842293906810036,
#   'ingeniousness': 0.0035842293906810036,
#   'dvr': 0.0035842293906810036,
#   'backpack': 0.0035842293906810036,
#   'holder': 0.0035842293906810036,
#   'layout': 0.0035842293906810036,
#   'machine': 0.0035842293906810036,
#   'internet': 0.007168458781362007,
#   'passionate': 0.0035842293906810036,
#   'floor': 0.0035842293906810036,
#   'imperfection': 0.0035842293906810036,
#   'cord': 0.0035842293906810036,
#   'set': 0.0035842293906810036,
#   'scalp': 0.0035842293906810036,
#   'band': 0.0035842293906810036,
#   'road': 0.0035842293906810036,
#   'dark': 0.0035842293906810036,
#   'warranty': 0.0035842293906810036,
#   'ear': 0.0035842293906810036,
#   'size': 0.0035842293906810036,
#   'older': 0.0035842293906810036,
#   'cap': 0.0035842293906810036,
#   'version': 0.0035842293906810036,
#   'dwl': 0.0035842293906810036,
#   'money': 0.0035842293906810036,
#   'hardware': 0.007168458781362007,
#   'windsheild': 0.0035842293906810036,
#   'power': 0.010752688172043012,
#   'end': 0.0035842293906810036,
#   'best': 0.0035842293906810036,
#   'bottom': 0.0035842293906810036,
#   'model': 0.0035842293906810036,
#   'airplane': 0.0035842293906810036,
#   'state': 0.0035842293906810036,
#   'office': 0.0035842293906810036,
#   'control': 0.0035842293906810036,
#   'eye': 0.0035842293906810036,
#   'kitchen': 0.0035842293906810036,
#   'base': 0.0035842293906810036,
#   'web': 0.0035842293906810036,
#   'generic': 0.0035842293906810036,
#   'lowrance': 0.0035842293906810036,
#   'window': 0.0035842293906810036,
#   'air': 0.0035842293906810036,
#   'wash': 0.0035842293906810036,
#   'outlet': 0.0035842293906810036,
#   'product': 0.0035842293906810036,
#   'country': 0.0035842293906810036,
#   'contract': 0.0035842293906810036,
#   'case': 0.0035842293906810036,
#   'one': 0.0035842293906810036,
#   'key': 0.0035842293906810036,
#   'package': 0.0035842293906810036,
#   'stand': 0.0035842293906810036,
#   'lowrence': 0.0035842293906810036,
#   'gps': 0.0035842293906810036,
#   'satellite': 0.0035842293906810036,
#   'resolution': 0.0035842293906810036,
#   'yard': 0.0035842293906810036,
#   'function': 0.0035842293906810036,
#   'list': 0.0035842293906810036,
#   'in': 0.0035842293906810036,
#   'gamepad': 0.0035842293906810036,
#   'pad': 0.0035842293906810036,
#   'reception': 0.0035842293906810036,
#   'display': 0.0035842293906810036,
#   'street': 0.0035842293906810036,
#   'adapter': 0.0035842293906810036},
#  ('and', 'this'): {'with': 0.037037037037037035,
#   'using': 0.037037037037037035,
#   'reliable': 0.037037037037037035,
#   'feel': 0.037037037037037035,
#   'feature': 0.037037037037037035,
#   'found': 0.037037037037037035,
#   'buy': 0.037037037037037035,
#   'whistle': 0.037037037037037035,
#   'mile': 0.037037037037037035,
#   'tracking': 0.037037037037037035,
#   'chose': 0.037037037037037035,
#   'mention': 0.037037037037037035,
#   'picked': 0.037037037037037035,
#   'elsewhere': 0.037037037037037035,
#   'stumbled': 0.037037037037037035,
#   'use': 0.07407407407407407,
#   'deemed': 0.037037037037037035,
#   'keeping': 0.037037037037037035,
#   'family': 0.037037037037037035,
#   'overall': 0.037037037037037035,
#   'superb': 0.037037037037037035,
#   'pop': 0.037037037037037035,
#   'recommend': 0.037037037037037035,
#   'preamp': 0.037037037037037035,
#   'surround': 0.037037037037037035,
#   'shoulder': 0.037037037037037035},
#  ('this', 'could'): {'reader': 0.2,
#   'because': 0.2,
#   'you': 0.2,
#   'but': 0.2,
#   'dashmount': 0.2},
#  ('camera', 'it'): {'and': 0.5, 'with': 0.5},
#  ('and', 'cable'): {'it': 0.2,
#   'for': 0.2,
#   'speaker': 0.2,
#   'regular': 0.2,
#   'the': 0.2},
#  ('it', 'and'): {'case': 0.14285714285714285,
#   'rating': 0.14285714285714285,
#   'large': 0.14285714285714285,
#   'screen': 0.14285714285714285,
#   'cute': 0.2857142857142857,
#   'price': 0.14285714285714285},
#  ('and', 'download'): {'just': 0.3333333333333333,
#   'transfering': 0.3333333333333333,
#   'almanac': 0.3333333333333333},
#  ('just', 'the'): {'download': 0.03333333333333333,
#   'adjusting': 0.03333333333333333,
#   'added': 0.03333333333333333,
#   'simply': 0.03333333333333333,
#   'followed': 0.03333333333333333,
#   'put': 0.03333333333333333,
#   'fit': 0.03333333333333333,
#   'like': 0.06666666666666667,
#   'wish': 0.06666666666666667,
#   'focus': 0.03333333333333333,
#   'right': 0.03333333333333333,
#   'wanted': 0.03333333333333333,
#   'carried': 0.03333333333333333,
#   'happens': 0.03333333333333333,
#   'blocked': 0.03333333333333333,
#   'color': 0.03333333333333333,
#   'want': 0.03333333333333333,
#   'connect': 0.03333333333333333,
#   'place': 0.03333333333333333,
#   'spent': 0.03333333333333333,
#   'love': 0.03333333333333333,
#   'often': 0.03333333333333333,
#   'great': 0.03333333333333333,
#   'careful': 0.03333333333333333,
#   'awesome': 0.03333333333333333,
#   'well': 0.03333333333333333,
#   'excercising': 0.03333333333333333,
#   'use': 0.03333333333333333},
#  ('the', 'with'): {'picture': 0.03773584905660377,
#   'junction': 0.018867924528301886,
#   'unit': 0.018867924528301886,
#   'lens': 0.018867924528301886,
#   'instruction': 0.018867924528301886,
#   'cloth': 0.018867924528301886,
#   'gps': 0.03773584905660377,
#   'tweaking': 0.018867924528301886,
#   'speaker': 0.03773584905660377,
#   'earphone': 0.018867924528301886,
#   'one': 0.03773584905660377,
#   'system': 0.018867924528301886,
#   'telephone': 0.03773584905660377,
#   'remote': 0.018867924528301886,
#   'phone': 0.05660377358490566,
#   'pip': 0.018867924528301886,
#   'mouse': 0.03773584905660377,
#   'compatible': 0.018867924528301886,
#   'oven': 0.018867924528301886,
#   'station': 0.018867924528301886,
#   'way': 0.018867924528301886,
#   'music': 0.018867924528301886,
#   'handset': 0.018867924528301886,
#   'control': 0.018867924528301886,
#   'album': 0.018867924528301886,
#   'problem': 0.05660377358490566,
#   'ysp': 0.018867924528301886,
#   'menu': 0.018867924528301886,
#   'same': 0.018867924528301886,
#   'dice': 0.018867924528301886,
#   'ease': 0.03773584905660377,
#   'sling': 0.018867924528301886,
#   'backpack': 0.018867924528301886,
#   'stand': 0.018867924528301886,
#   'car': 0.018867924528301886,
#   'uplink': 0.018867924528301886,
#   'air': 0.018867924528301886,
#   'grave': 0.018867924528301886,
#   'kos': 0.018867924528301886,
#   'locked': 0.018867924528301886,
#   'ique': 0.018867924528301886,
#   'window': 0.018867924528301886},
#  ('picture', 'the'): {'with': 0.2,
#   'jpegs': 0.2,
#   'from': 0.2,
#   'over': 0.2,
#   'centered': 0.2},
#  ('with', 'memory'): {'the': 0.2,
#   'sony': 0.2,
#   'lesser': 0.2,
#   'some': 0.2,
#   'expandable': 0.2},
#  ('the', 'card'): {'memory': 0.16666666666666666,
#   'new': 0.08333333333333333,
#   'lexar': 0.08333333333333333,
#   'standard': 0.16666666666666666,
#   'provided': 0.08333333333333333,
#   'quadro': 0.08333333333333333,
#   'gift': 0.08333333333333333,
#   'display': 0.08333333333333333,
#   'adapter': 0.08333333333333333,
#   'credit': 0.08333333333333333},
#  ('device', 'not'): {'there': 0.5, 'will': 0.25, 'ha': 0.25},
#  ('not', 'about'): {'say': 0.2857142857142857,
#   'sure': 0.14285714285714285,
#   'thinking': 0.14285714285714285,
#   'know': 0.14285714285714285,
#   'great': 0.14285714285714285,
#   'sorry': 0.14285714285714285},
#  ('than', 'the'): {'doe': 0.1111111111111111,
#   'over': 0.05555555555555555,
#   'using': 0.05555555555555555,
#   'with': 0.2222222222222222,
#   'some': 0.05555555555555555,
#   'said': 0.05555555555555555,
#   'either': 0.05555555555555555,
#   'the': 0.1111111111111111,
#   'expected': 0.05555555555555555,
#   'most': 0.05555555555555555,
#   'movie': 0.05555555555555555,
#   'offset': 0.05555555555555555,
#   'red': 0.05555555555555555},
#  ('doe', 'job'): {'the': 0.4,
#   'great': 0.13333333333333333,
#   'it': 0.06666666666666667,
#   'excellent': 0.06666666666666667,
#   'good': 0.13333333333333333,
#   'fine': 0.06666666666666667,
#   'decent': 0.06666666666666667,
#   'nice': 0.06666666666666667},
#  ('the', 'you'): {'job': 0.024390243902439025,
#   'disk': 0.012195121951219513,
#   'adapter': 0.012195121951219513,
#   'side': 0.012195121951219513,
#   'pouch': 0.012195121951219513,
#   'money': 0.06097560975609756,
#   'then': 0.012195121951219513,
#   'further': 0.012195121951219513,
#   'price': 0.0975609756097561,
#   'bose': 0.012195121951219513,
#   'presets': 0.012195121951219513,
#   'scientist': 0.012195121951219513,
#   'box': 0.012195121951219513,
#   'ipod': 0.036585365853658534,
#   'game': 0.012195121951219513,
#   'cost': 0.012195121951219513,
#   'radio': 0.012195121951219513,
#   'left': 0.012195121951219513,
#   'way': 0.024390243902439025,
#   'longer': 0.012195121951219513,
#   'fly': 0.012195121951219513,
#   'reason': 0.012195121951219513,
#   'product': 0.024390243902439025,
#   'base': 0.012195121951219513,
#   'fact': 0.024390243902439025,
#   'usa': 0.012195121951219513,
#   'contract': 0.024390243902439025,
#   'software': 0.012195121951219513,
#   'table': 0.012195121951219513,
#   'smoker': 0.012195121951219513,
#   'player': 0.024390243902439025,
#   'voice': 0.012195121951219513,
#   'range': 0.012195121951219513,
#   'picture': 0.012195121951219513,
#   'back': 0.012195121951219513,
#   'remote': 0.012195121951219513,
#   'mouse': 0.012195121951219513,
#   'route': 0.012195121951219513,
#   'walking': 0.012195121951219513,
#   'dock': 0.012195121951219513,
#   'holiday': 0.012195121951219513,
#   'charger': 0.012195121951219513,
#   'country': 0.012195121951219513,
#   'and': 0.012195121951219513,
#   'manual': 0.012195121951219513,
#   'speaker': 0.012195121951219513,
#   'louder': 0.012195121951219513,
#   'book': 0.012195121951219513,
#   'end': 0.012195121951219513,
#   'accesories': 0.012195121951219513,
#   'car': 0.012195121951219513,
#   'best': 0.012195121951219513,
#   'airport': 0.012195121951219513,
#   'more': 0.012195121951219513,
#   'market': 0.012195121951219513,
#   'screen': 0.012195121951219513,
#   'right': 0.012195121951219513,
#   'documentation': 0.012195121951219513,
#   'part': 0.012195121951219513,
#   'thing': 0.012195121951219513,
#   'internet': 0.012195121951219513,
#   'recording': 0.012195121951219513,
#   'list': 0.012195121951219513},
#  ('should', 'that'): {'note': 0.25, 'noted': 0.125, 'know': 0.5, 'say': 0.125},
#  ('note', 'the'): {'that': 0.5,
#   'brian': 0.125,
#   'some': 0.125,
#   'twords': 0.125,
#   'regarding': 0.125},
#  ('the', 'the'): {'led': 0.0057306590257879654,
#   'price': 0.017191977077363897,
#   'keyboard': 0.0057306590257879654,
#   'video': 0.0057306590257879654,
#   'quality': 0.02865329512893983,
#   'majority': 0.0028653295128939827,
#   'remote': 0.0028653295128939827,
#   'best': 0.011461318051575931,
#   'attachment': 0.0028653295128939827,
#   'chasis': 0.0028653295128939827,
#   'recording': 0.0057306590257879654,
#   'hang': 0.0057306590257879654,
#   'money': 0.0057306590257879654,
#   'bedroom': 0.0028653295128939827,
#   'feature': 0.008595988538681949,
#   'outside': 0.0057306590257879654,
#   'find': 0.0028653295128939827,
#   'ground': 0.0028653295128939827,
#   'top': 0.02005730659025788,
#   'unit': 0.0057306590257879654,
#   'daylight': 0.0028653295128939827,
#   'weight': 0.0057306590257879654,
#   'radio': 0.0057306590257879654,
#   'roar': 0.0028653295128939827,
#   'front': 0.014326647564469915,
#   'receiver': 0.0057306590257879654,
#   'middle': 0.0057306590257879654,
#   'bass': 0.0057306590257879654,
#   'manual': 0.0028653295128939827,
#   'tray': 0.0028653295128939827,
#   'click': 0.0028653295128939827,
#   'durability': 0.0028653295128939827,
#   'and': 0.0057306590257879654,
#   'store': 0.0028653295128939827,
#   'competition': 0.0028653295128939827,
#   'handset': 0.0057306590257879654,
#   'ruggedness': 0.0028653295128939827,
#   'way': 0.02005730659025788,
#   'piano': 0.0028653295128939827,
# ...
#   'music': 0.045454545454545456,
#   'requirement': 0.045454545454545456,
#   'stx': 0.045454545454545456,
#   'fit': 0.045454545454545456,
#   'review': 0.045454545454545456,
#   'sound': 0.13636363636363635,
#   'price': 0.09090909090909091,
#   'clickwheel': 0.045454545454545456,
#   'phone': 0.045454545454545456,
#   'picture': 0.045454545454545456,
#   'background': 0.045454545454545456,
#   'reception': 0.045454545454545456,
#   'another': 0.045454545454545456,
#   'same': 0.045454545454545456,
#   'sennheiser': 0.045454545454545456,
#   'isqueez': 0.045454545454545456,
#   'ipod': 0.045454545454545456,
#   'clarity': 0.045454545454545456},
#  ('the', 'work'): {'product': 0.08333333333333333,
#   'changer': 0.027777777777777776,
#   'card': 0.027777777777777776,
#   'unit': 0.027777777777777776,
#   'hub': 0.027777777777777776,
#   'accesories': 0.027777777777777776,
#   'system': 0.05555555555555555,
#   'software': 0.027777777777777776,
#   'monitor': 0.027777777777777776,
#   'pico': 0.027777777777777776,
#   'cid': 0.027777777777777776,
#   'base': 0.027777777777777776,
#   'functionality': 0.027777777777777776,
#   'medium': 0.027777777777777776,
#   'charger': 0.027777777777777776,
#   'handset': 0.027777777777777776,
#   'wifi': 0.027777777777777776,
#   'dark': 0.027777777777777776,
#   'smallest': 0.027777777777777776,
#   'volume': 0.027777777777777776,
#   'player': 0.027777777777777776,
#   'headset': 0.027777777777777776,
#   'upconvert': 0.027777777777777776,
#   'game': 0.027777777777777776,
#   'box': 0.027777777777777776,
#   'dash': 0.027777777777777776,
#   'best': 0.027777777777777776,
#   'cordless': 0.027777777777777776,
#   'signal': 0.027777777777777776,
#   'printer': 0.027777777777777776,
#   'antenna': 0.027777777777777776,
#   'phone': 0.027777777777777776,
#   'gps': 0.027777777777777776},
#  ('work', 'ipod'): {'well': 0.3333333333333333, 'with': 0.6666666666666666},
#  ('old', 'video'): {'music': 0.5, 'home': 0.5},
#  ('music', 'and'): {'video': 0.125,
#   'great': 0.125,
#   'playing': 0.125,
#   'lover': 0.125,
#   'quality': 0.125,
#   'player': 0.125,
#   'game': 0.125,
#   'function': 0.125},
#  ('and', 'for'): {'movie': 0.03333333333333333,
#   'brightness': 0.03333333333333333,
#   'perfect': 0.06666666666666667,
#   'voice': 0.03333333333333333,
#   'release': 0.03333333333333333,
#   'comfortable': 0.03333333333333333,
#   'pay': 0.03333333333333333,
#   'searched': 0.06666666666666667,
#   'make': 0.03333333333333333,
#   'gui': 0.03333333333333333,
#   'affordable': 0.03333333333333333,
#   'toner': 0.03333333333333333,
#   'show': 0.03333333333333333,
#   'poi': 0.03333333333333333,
#   'leg': 0.03333333333333333,
#   'work': 0.03333333333333333,
#   'waited': 0.03333333333333333,
#   'occasionally': 0.03333333333333333,
#   'play': 0.03333333333333333,
#   'got': 0.03333333333333333,
#   'shipped': 0.03333333333333333,
#   'charger': 0.03333333333333333,
#   'good': 0.03333333333333333,
#   'using': 0.03333333333333333,
#   'now': 0.03333333333333333,
#   'yoke': 0.03333333333333333,
#   'over': 0.03333333333333333,
#   'paid': 0.03333333333333333},
#  ('real', 'sound'): {'treat': 0.5, 'professional': 0.5},
#  ('this', 'printer'): {'photo': 0.3333333333333333,
#   'great': 0.3333333333333333,
#   'regular': 0.3333333333333333},
#  ('now', 'consider'): {'don': 0.5, 'and': 0.5},
#  ('with', 'machine'): {'this': 0.3333333333333333,
#   'the': 0.3333333333333333,
#   'answering': 0.3333333333333333},
#  ('can', 'wrong'): {'not': 0.5, 'never': 0.25, 'you': 0.25},
#  ('quality', 'and'): {'photo': 0.11764705882352941,
#   'product': 0.11764705882352941,
#   'headphone': 0.058823529411764705,
#   'excellent': 0.11764705882352941,
#   'sound': 0.058823529411764705,
#   'clean': 0.058823529411764705,
#   'plastic': 0.058823529411764705,
#   'standpoint': 0.058823529411764705,
#   'performance': 0.058823529411764705,
#   'teriffic': 0.058823529411764705,
#   'material': 0.058823529411764705,
#   'value': 0.058823529411764705,
#   'decent': 0.058823529411764705,
#   'convenient': 0.058823529411764705},
#  ('the', 'are'): {'result': 0.011111111111111112,
#   'negative': 0.022222222222222223,
#   'battery': 0.022222222222222223,
#   'earphone': 0.011111111111111112,
#   'review': 0.011111111111111112,
#   'sony': 0.011111111111111112,
#   'speaker': 0.05555555555555555,
#   'ssmf': 0.011111111111111112,
#   'high': 0.011111111111111112,
#   'cartridge': 0.03333333333333333,
#   'control': 0.03333333333333333,
#   'weakness': 0.011111111111111112,
#   'feature': 0.03333333333333333,
#   'jack': 0.011111111111111112,
#   'earbuds': 0.011111111111111112,
#   'phone': 0.011111111111111112,
#   'wire': 0.022222222222222223,
#   'bud': 0.011111111111111112,
#   'keyz': 0.011111111111111112,
#   'you': 0.011111111111111112,
#   'print': 0.03333333333333333,
#   'headphone': 0.03333333333333333,
#   'and': 0.011111111111111112,
#   'the': 0.011111111111111112,
#   'jbls': 0.011111111111111112,
#   'key': 0.03333333333333333,
#   'samsungs': 0.011111111111111112,
#   'light': 0.011111111111111112,
#   'keyboard': 0.011111111111111112,
#   'call': 0.011111111111111112,
#   'basslines': 0.011111111111111112,
#   'button': 0.044444444444444446,
#   'base': 0.011111111111111112,
#   'dimension': 0.011111111111111112,
#   'cymbal': 0.011111111111111112,
#   'instruction': 0.011111111111111112,
#   'printing': 0.011111111111111112,
#   'hole': 0.011111111111111112,
#   'file': 0.011111111111111112,
#   'direction': 0.022222222222222223,
#   'laptop': 0.011111111111111112,
#   'dvd': 0.011111111111111112,
#   'port': 0.011111111111111112,
#   'color': 0.022222222222222223,
#   'screen': 0.011111111111111112,
#   'amplifier': 0.011111111111111112,
#   'price': 0.011111111111111112,
#   'operation': 0.011111111111111112,
#   'road': 0.011111111111111112,
#   'cup': 0.011111111111111112,
#   'clock': 0.011111111111111112,
#   'model': 0.011111111111111112,
#   'picture': 0.011111111111111112,
#   'pro': 0.011111111111111112,
#   'monitor': 0.011111111111111112,
#   'connection': 0.011111111111111112,
#   'handset': 0.03333333333333333,
#   'pda': 0.011111111111111112,
#   'map': 0.011111111111111112,
#   'problem': 0.011111111111111112,
#   'con': 0.011111111111111112,
#   'unit': 0.011111111111111112,
#   'menu': 0.011111111111111112,
#   'scan': 0.011111111111111112},
#  ('for', 'who'): {'someone': 0.14814814814814814,
#   'those': 0.3333333333333333,
#   'anybody': 0.037037037037037035,
#   'sister': 0.037037037037037035,
#   'student': 0.037037037037037035,
#   'people': 0.14814814814814814,
#   'anyone': 0.14814814814814814,
#   'son': 0.037037037037037035,
#   'somone': 0.037037037037037035,
#   'wife': 0.037037037037037035},
#  ('case', 'the'): {'equal': 0.07692307692307693,
#   'cover': 0.15384615384615385,
#   'protect': 0.07692307692307693,
#   'for': 0.07692307692307693,
#   'and': 0.15384615384615385,
#   'after': 0.07692307692307693,
#   'above': 0.07692307692307693,
#   'run': 0.07692307692307693,
#   'protects': 0.07692307692307693,
#   'hold': 0.07692307692307693,
#   'come': 0.07692307692307693},
#  ('buy', 'and'): {'them': 0.25,
#   'without': 0.25,
#   'transmitter': 0.25,
#   'store': 0.25},
#  ('and', 'space'): {'conserve': 0.5, 'wall': 0.5},
#  ('found', 'that'): {'out': 0.875, 'far': 0.125},
#  ('are', 'better'): {'much': 0.3333333333333333,
#   'great': 0.3333333333333333,
#   'far': 0.3333333333333333},
#  ('better', 'the'): {'than': 0.4444444444444444,
#   'thru': 0.037037037037037035,
#   'saved': 0.037037037037037035,
#   'picture': 0.037037037037037035,
#   'then': 0.07407407407407407,
#   'with': 0.037037037037037035,
#   'neither': 0.037037037037037035,
#   'yet': 0.037037037037037035,
#   'look': 0.037037037037037035,
#   'let': 0.037037037037037035,
#   'that': 0.037037037037037035,
#   'talk': 0.037037037037037035,
#   'product': 0.037037037037037035,
#   'for': 0.037037037037037035,
#   'printer': 0.037037037037037035},
#  ('than', 'one'): {'the': 0.38461538461538464,
#   'excellent': 0.07692307692307693,
#   'old': 0.07692307692307693,
#   'new': 0.07692307692307693,
#   'either': 0.07692307692307693,
#   'this': 0.15384615384615385,
#   'previous': 0.07692307692307693,
#   'epson': 0.07692307692307693},
#  ('the', 'sold'): {'one': 0.5, 'unit': 0.5},
#  ('here', 'and'): {'locally': 0.5, 'spot': 0.5},
#  ('and', 'were'): {'they': 0.2727272727272727,
#   'effort': 0.09090909090909091,
#   'picture': 0.18181818181818182,
#   'the': 0.09090909090909091,
#   'sennheiser': 0.09090909090909091,
#   'volume': 0.09090909090909091,
#   'there': 0.09090909090909091,
#   'delivery': 0.09090909090909091},
#  ('like', 'all'): {'keeping': 0.25,
#   'hearing': 0.25,
#   'listen': 0.25,
#   'echo': 0.25},
#  ('all', 'one'): {'stuff': 0.25, 'and': 0.25, 'control': 0.25, 'this': 0.25},
#  ('one', 'but'): {'place': 0.25, 'again': 0.25, 'did': 0.25, 'time': 0.25},
#  ('but', 'like'): {'don': 0.2,
#   'function': 0.2,
#   'basically': 0.2,
#   'seems': 0.2,
#   'didn': 0.2},
#  ('like', 'these'): {'folder': 0.3333333333333333,
#   'about': 0.3333333333333333,
#   'game': 0.3333333333333333},
#  ('case', 'great'): {'are': 0.5, 'still': 0.5},
#  ('and', 'did'): {'although': 0.5, 'firmware': 0.5},
#  ('break', 'the'): {'and': 0.3333333333333333,
#   'all': 0.3333333333333333,
#   'them': 0.3333333333333333},
#  ('the', 'fine'): {'wa': 0.2,
#   'backlight': 0.2,
#   'sound': 0.2,
#   'product': 0.2,
#   'display': 0.2},
#  ('fine', 'all'): {'all': 0.6666666666666666, 'and': 0.3333333333333333},
#  ('all', 'product'): {'great': 0.5, 'good': 0.5},
#  ('used', 'and'): {'these': 0.2,
#   'this': 0.2,
#   'make': 0.2,
#   'winplay': 0.2,
#   'audiophile': 0.2},
#  ('and', 'case'): {'similar': 0.16666666666666666,
#   'these': 0.16666666666666666,
#   'all': 0.16666666666666666,
#   'this': 0.16666666666666666,
#   'simple': 0.16666666666666666,
#   'both': 0.16666666666666666},
#  ('for', 'problem'): {'year': 0.5, 'the': 0.5},
#  ('problem', 'with'): {'even': 0.1111111111111111,
#   'using': 0.1111111111111111,
#   'isn': 0.1111111111111111,
#   'all': 0.1111111111111111,
#   'had': 0.3333333333333333,
#   'initially': 0.1111111111111111,
#   'wa': 0.1111111111111111},
#  ('them', 'and'): {'around': 0.16666666666666666,
#   'back': 0.16666666666666666,
#   'for': 0.16666666666666666,
#   'new': 0.16666666666666666,
#   'store': 0.16666666666666666,
#   'both': 0.16666666666666666},
#  ('one', 'they'): {'crack': 0.5, 'back': 0.5},
#  ('disc', 'but'): {'securely': 0.5, 'functioning': 0.5},
#  ('but', 'with'): {'not': 0.1111111111111111,
#   'pleased': 0.1111111111111111,
#   'far': 0.1111111111111111,
#   'ended': 0.1111111111111111,
#   'impressed': 0.1111111111111111,
#   'interferes': 0.1111111111111111,
#   'happy': 0.1111111111111111,
#   'that': 0.1111111111111111,
#   'webcam': 0.1111111111111111},
#  ('not', 'much'): {'with': 0.3333333333333333,
#   'know': 0.3333333333333333,
#   'make': 0.3333333333333333},
#  ('much', 'that'): {'force': 0.3333333333333333,
#   'better': 0.3333333333333333,
#   'considering': 0.3333333333333333},
#  ('the', 'when'): {'disc': 0.05263157894736842,
#   'machine': 0.05263157894736842,
#   'inside': 0.05263157894736842,
#   'case': 0.05263157894736842,
#   'battery': 0.05263157894736842,
#   'version': 0.05263157894736842,
#   'monitor': 0.05263157894736842,
#   'manual': 0.05263157894736842,
#   'early': 0.05263157894736842,
#   'past': 0.05263157894736842,
#   'thing': 0.05263157894736842,
#   'connector': 0.05263157894736842,
#   'and': 0.05263157894736842,
#   'grip': 0.05263157894736842,
#   'unit': 0.05263157894736842,
#   'moment': 0.05263157894736842,
#   'strongest': 0.05263157894736842,
#   'floor': 0.05263157894736842,
#   'radio': 0.05263157894736842},
#  ('you', 'them'): {'open': 0.14285714285714285,
#   'made': 0.14285714285714285,
#   'use': 0.14285714285714285,
#   'press': 0.14285714285714285,
#   'remove': 0.14285714285714285,
#   'tried': 0.14285714285714285,
#   'put': 0.14285714285714285},
#  ('them', 'from'): {'properly': 0.25,
#   'around': 0.25,
#   'directly': 0.25,
#   'away': 0.25},
#  ('pulling', 'the'): {'near': 0.5, 'back': 0.5},
#  ('the', 'while'): {'corner': 0.1111111111111111,
#   'output': 0.1111111111111111,
#   'song': 0.1111111111111111,
#   'nano': 0.1111111111111111,
#   'morning': 0.1111111111111111,
#   'ipod': 0.2222222222222222,
#   'gps': 0.1111111111111111,
#   'phone': 0.1111111111111111},
#  ('while', 'the'): {'holding': 0.14285714285714285,
#   'inserting': 0.14285714285714285,
#   'retaining': 0.14285714285714285,
#   'save': 0.14285714285714285,
#   'still': 0.14285714285714285,
#   'traveling': 0.14285714285714285,
#   'connected': 0.14285714285714285},
#  ('the', 'colored'): {'back': 0.5, 'lack': 0.5},
#  ('they', 'fine'): {'open': 0.3333333333333333,
#   'are': 0.3333333333333333,
#   'work': 0.3333333333333333},
#  ('for', 'dollar'): {'eight': 0.2, 'about': 0.4, 'your': 0.2, 'canadian': 0.2},
#  ('but', 'don'): {'they': 0.4, 'you': 0.4, 'worth': 0.2},
#  ('they', 'last'): {'don': 0.3333333333333333,
#   'will': 0.16666666666666666,
#   'would': 0.16666666666666666,
#   'seem': 0.16666666666666666,
#   'won': 0.16666666666666666},
#  ('last', 'long'): {'very': 0.5, 'good': 0.5},
#  ('for', 'camera'): {'digital': 0.5, 'the': 0.5},
#  ('that', 'they'): {'why': 0.2,
#   'what': 0.2,
#   'because': 0.2,
#   'instrument': 0.2,
#   'once': 0.2},
#  ('why', 'get'): {'they': 0.5, 'only': 0.5},
#  ('get', 'quickly'): {'drained': 0.5, 'annoying': 0.5},
#  ('however', 'the'): {'for': 0.125,
#   'recognize': 0.125,
#   'found': 0.125,
#   'that': 0.125,
#   'out': 0.125,
#   'with': 0.125,
#   'start': 0.125,
#   'the': 0.125},
#  ('the', 'still'): {'price': 0.16666666666666666,
#   'ipod': 0.16666666666666666,
#   'but': 0.16666666666666666,
#   'same': 0.16666666666666666,
#   'case': 0.16666666666666666,
#   'print': 0.16666666666666666},
#  ('still', 'buy'): {'would': 0.5, 'need': 0.5},
#  ('would', 'them'): {'buy': 0.3333333333333333,
#   'listen': 0.3333333333333333,
#   'reencode': 0.3333333333333333},
#  ('the', 'being'): {'option': 0.1111111111111111,
#   'advantage': 0.1111111111111111,
#   'scene': 0.1111111111111111,
#   'item': 0.2222222222222222,
#   'mistake': 0.1111111111111111,
#   'warranty': 0.1111111111111111,
#   'screen': 0.1111111111111111,
#   'kid': 0.1111111111111111},
#  ('have', 'several'): {'tried': 0.2, 'used': 0.4, 'owned': 0.4},
#  ('tried', 'brand'): {'several': 0.25,
#   'every': 0.25,
#   'many': 0.25,
#   'other': 0.25},
#  ('trying', 'the'): {'find': 0.25, 'enjoy': 0.25, 'buy': 0.25, 'fit': 0.25},
#  ('etc', 'need'): {'she': 0.5, 'you': 0.5},
#  ('need', 'them'): {'replace': 0.5, 'convert': 0.5},
#  ('and', 'since'): {'half': 0.5, 'there': 0.5},
#  ('the', 'high'): {'implant': 0.16666666666666666,
#   'ultra': 0.16666666666666666,
#   'material': 0.16666666666666666,
#   'sound': 0.16666666666666666,
#   'same': 0.16666666666666666,
#   'relatively': 0.16666666666666666},
#  ('hour', 'these'): {'count': 0.5, 'keeping': 0.5},
#  ('battery', 'one'): {'are': 0.5, 'this': 0.5},
#  ('the', 'value'): {'best': 0.5, 'real': 0.5},
#  ('for', 'apple'): {'this': 0.3333333333333333,
#   'the': 0.3333333333333333,
#   'and': 0.3333333333333333},
#  ('this', 'product'): {'apple': 0.07692307692307693,
#   'sangean': 0.07692307692307693,
#   'pocket': 0.07692307692307693,
#   'whole': 0.07692307692307693,
#   'great': 0.23076923076923078,
#   'fine': 0.07692307692307693,
#   'perfect': 0.07692307692307693,
#   'wonderful': 0.07692307692307693,
#   'the': 0.07692307692307693,
#   'excellent': 0.15384615384615385},
#  ('product', 'had'): {'however': 0.3333333333333333,
#   'star': 0.3333333333333333,
#   'always': 0.3333333333333333},
#  ('had', 'machine'): {'washing': 0.5, 'the': 0.5},
#  ('the', 'turned'): {'washer': 0.25,
#   'volume': 0.25,
#   'minute': 0.25,
#   'moment': 0.25},
#  ('those', 'that'): {'machine': 0.3333333333333333,
#   'company': 0.3333333333333333,
#   'outlet': 0.3333333333333333},
#  ('one', 'after'): {'problem': 0.5, 'own': 0.5},
#  ('another', 'the'): {'sometimes': 0.2,
#   'also': 0.2,
#   'pair': 0.2,
#   'recording': 0.2,
#   'vehicle': 0.2},
#  ('the', 'used'): {'same': 0.25,
#   'summer': 0.125,
#   'volume': 0.125,
#   'message': 0.125,
#   'set': 0.125,
#   'mount': 0.125,
#   'printer': 0.125},
#  ('and', 'every'): {'made': 0.25,
#   'use': 0.25,
#   'loved': 0.25,
#   'responsive': 0.25},
#  ('machine', 'the'): {'when': 0.14285714285714285,
#   'check': 0.14285714285714285,
#   'but': 0.14285714285714285,
#   'with': 0.14285714285714285,
#   'built': 0.14285714285714285,
#   'physically': 0.14285714285714285,
#   'like': 0.14285714285714285},
#  ('check', 'the'): {'for': 0.25, 'out': 0.75},
#  ('for', 'amount'): {'the': 0.5, 'certain': 0.5},
#  ...}

# %%
M[:2], pi[:1]
# Out:
# (array([[7.04046861e-05, 2.76127179e-02, 3.36111972e-02, 4.38621195e-02,
#          4.22428117e-04, 8.73018108e-03, 2.05018446e-02, 1.08704835e-02,
#          4.75090822e-02, 2.95699682e-04, 1.45456082e-02, 1.10633924e-01,
#          2.53034442e-02, 2.09721479e-01, 2.11214058e-04, 2.34306795e-02,
#          7.04046861e-05, 1.08395055e-01, 9.77076234e-02, 1.42217466e-01,
#          7.92756766e-03, 2.33602749e-02, 1.04198935e-02, 4.50589991e-04,
#          2.94854826e-02, 2.63313526e-03],
#         [6.00292826e-02, 2.66089503e-02, 6.36577758e-05, 5.72919982e-04,
#          2.54949392e-01, 6.36577758e-05, 1.27315552e-04, 4.45604431e-04,
#          3.79400344e-02, 5.47456872e-03, 6.36577758e-05, 1.20567827e-01,
#          8.91208861e-04, 1.27315552e-04, 1.52333057e-01, 6.36577758e-05,
#          6.36577758e-05, 5.88197848e-02, 1.89063594e-02, 7.25698644e-03,
#          1.67483608e-01, 8.27551085e-04, 1.27315552e-04, 6.36577758e-05,
#          8.60653129e-02, 6.36577758e-05]]), array([0.10945403]))

# %%
# Random sample from probs
def random_sample(probs_dict, size):
    return np.random.choice(list(probs_dict.keys()), size, list(probs_dict.values()))[0]

# %% [markdown]
# ## test spinner

# %%
def my_tokenizer(sentence:str):
#     s = sentence.lower()
#     s = regex.sub(' ', s) 
    tokens = nltk.tokenize.word_tokenize(sentence)
#     tokens = [t for t in tokens if len(t) > 2]
#     tokens = [lemmatizer.lemmatize(t) for t in tokens]
#     tokens = [t for t in tokens if t not in stopwords]

    return tokens


def test_spinner(reviews):
    review = np.random.choice(reviews)
    print("Original:\n ", review)
    tokens = my_tokenizer(review)
    for i, token in enumerate(tokens[:-2]):
        if random.random() < 0.2:
            k = (tokens[i], tokens[i+2])
            if k in trigrams_probabilities:
                w = random_sample(trigrams_probabilities[k], 1)
                print(f"we will substitute '{tokens[i+1]}' --> {w}!")
                tokens[i+1] = "***" + w + "***"
                

    print("spun: ")
    try: 
        print(" ".join(tokens))
    except:
        print(tokens)

# %%
t = "Works great, good quality from Belkin as usual. Hard to beat for the money"
rs = [r.text for r in positive_reviews]
test_spinner(rs)
# np.random.choice([r.text for r in positive_reviews])
# Out:
# Original:
#
# I researched cases upon receipt of my 20 GB iPod and deemed this the best.  This case consists of a thin plastic sleeve inside a separate clear, hard shell.  The hard case protects the iPod from scratches and minor falls while still allowing easy access to the controls and inputs.  It also does not obscure the screen.  An enclosed plastic belt clip attaches to the back of the unit.
# This case is not compatible with a Bose Sounddock as the user must remove the iPod from the case.  Also, Contour Design only enclosed one of the thin plastic sleeves.  I spent $5 at their website for 5 more sleeves and gave some to friends with the same case.
# The price seems high for a couple pieces of plastic but a case is essential and this is the best one for the 20 GB iPod.
#
# we will substitute 'is' --> hit!
# we will substitute 'enclosed' --> required!
# we will substitute 'website' --> office!
# we will substitute '5' --> about!
# we will substitute 'gave' --> listened!
# we will substitute 'same' --> carrying!
# we will substitute 'seems' --> seems!
# we will substitute 'one' --> one!
# spun:
# I researched cases upon receipt of my 20 GB iPod and deemed this the best . This case consists of a thin plastic sleeve inside a separate clear , hard shell . The hard case protects the iPod from scratches and minor falls while still allowing easy access to the controls and inputs . It also does not obscure the screen . An enclosed plastic belt clip attaches to the back of the unit . This case ***hit*** not compatible with a Bose Sounddock as the user must remove the iPod from the case . Also , Contour Design only ***required*** one of the thin plastic sleeves . I spent $ 5 at their ***office*** for ***about*** more sleeves and ***listened*** some to friends with the ***carrying*** case . The price ***seems*** high for a couple pieces of plastic but a case is essential and this is the best ***one*** for the 20 GB iPod .

# %%
tokens
# Out:
# ['the',
#  'gps',
#  'work',
#  'both',
#  'dell',
#  'axim',
#  'and',
#  'compaq',
#  'with',
#  'compact',
#  'flash',
#  'adapter',
#  'card',
#  'have',
#  'used',
#  'with',
#  'street',
#  'and',
#  'trip',
#  'and',
#  'arcpad']
